# %%
import re
import json
import collections
from constants import START_TOKEN, END_TOKEN

# %%
def get_train_image_captions_mapping():
    """
    Returns a dictionary mapping image path to the list of captions
    :return: dict {image_path: [caption1, caption2, ...]}
    """
    try:
        result = {}
        with open('data/annotations/captions_train2014.json', 'r') as f:
            annotations = json.load(f)
            for val in annotations['annotations']:
                caption = f"{val['caption']}"
                image_path = '/data/train/' + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
                result.setdefault(image_path, []).append(caption)
        return result
    except FileNotFoundError:
        print("Don't have the annotations file. Please run data_download.py to download the data.")

# %%
def clean_bad_text_data(image_captions_mapping):
    """
    Removes punctuation and numbers, conver to lower from the captions
    """
    for path, captions in image_captions_mapping.items():
        for i in range(len(captions)):
            cap = captions[i]
            cap = cap.split()

            # convert to lower case
            cap = [w.lower() for w in cap if w]

            # remove punctuation from each token
            cap = [re.sub(r'[^\w\s]','',w) for w in cap]

            # remove tokens with numbers in them
            cap = [w for w in cap if w.isalpha()]

            captions[i] =  ' '.join(cap)
            
    return image_captions_mapping

# %%
a = get_train_image_captions_mapping()
clean_bad_text_data(a)
# Out:
# {'/data/train/COCO_train2014_000000318556.jpg': ['a very clean and well decorated empty bathroom',
#   'a blue and white bathroom with butterfly themed wall tiles',
#   'a bathroom with a border of butterflies and blue paint on the walls above it',
#   'an angled view of a beautifully decorated bathroom',
#   'a clock that blends in with the wall hangs in a bathroom'],
#  '/data/train/COCO_train2014_000000116100.jpg': ['a panoramic view of a kitchen and all of its appliances',
#   'a panoramic photo of a kitchen and dining room',
#   'a wide angle view of the kitchen work area',
#   'multiple photos of a brown and white kitchen',
#   'a kitchen that has a checkered patterned floor and white cabinets'],
#  '/data/train/COCO_train2014_000000379340.jpg': ['a graffitied stop sign across the street from a red car',
#   'a vandalized stop sign and a red beetle on the road',
#   'a red stop sign with a bush bumper sticker under the word stop',
#   'a stop sign that has been vandalized is pictured in front of a parked car',
#   'a street sign modified to read stop bush'],
#  '/data/train/COCO_train2014_000000134754.jpg': ['the two people are walking down the beach',
#   'two people carrying surf boards on a beach',
#   'two teenagers at a white sanded beach with surfboards',
#   'a couple at the beach walking with their surf boards',
#   'a guy and a girl are walking on the beach holding surfboards'],
#  '/data/train/COCO_train2014_000000538480.jpg': ['a sink and a toilet inside a small bathroom',
#   'white pedestal sink and toilet located in a poorly lit bathroom',
#   'clean indoor bathroom with tiled floor and good lighting',
#   'a bathroom with toilet and sink and blue wall',
#   'a blue bathroom with a sink and toilet'],
#  '/data/train/COCO_train2014_000000476220.jpg': ['an empty kitchen with white and black appliances',
#   'a refrigerator and stove are in a small kitchen area',
#   'small kitchen in a personal home with dual sinks',
#   'a small kitchen with sink stove and refrigerator',
#   'a small kitchen with several appliances and cookware'],
#  '/data/train/COCO_train2014_000000299675.jpg': ['a white square kitchen with tile floor that needs repairs',
#   'a white kitchen in a home with the light on',
#   'a kitchen with a tile floor has cabinets with no doors a dishwasher a sink and a refrigerator',
#   'a white kitchen without doors on the cabinets',
#   'a white kitchen filled with pots pans and dishes'],
#  '/data/train/COCO_train2014_000000032275.jpg': ['the vanity contains two sinks with a towel for each',
#   'a clean restroom with towels and washcloths laid out',
#   'the bathroom counter is stocked with towels and supplies',
#   'there is a clean bathroom counter and sink',
#   'a hotel bathroom with stone counter and mirror'],
#  '/data/train/COCO_train2014_000000302443.jpg': ['several metal balls sit in the sand near a group of people',
#   'people standing around many silver round balls on the ground',
#   'silver balls are lined up in the sand as people mill about in the background',
#   'silver balls on sand with people walking around',
#   'silver balls laying on the ground around a smaller red ball'],
#  '/data/train/COCO_train2014_000000025470.jpg': ['a kitchen with brown cabinets tile backsplash and grey counters',
#   'a kitchen contains black countertops brown cabinets and a red and white tile blacksplash',
#   'a clean organized kitchen cabinet and countertop area',
#   'a kitchen has red bricks lining the counter',
#   'a kitchen with wood cabinets and granite counter tops'],
#  '/data/train/COCO_train2014_000000513461.jpg': ['a surfer a woman and a child walk on the beach',
#   'a person holding a surf board on a beach',
#   'a family standing next to the ocean on a sandy beach with a surf board',
#   'a man getting ready to surf as lookers walk by',
#   'a family carrying a surfboard to the ocean'],
#  '/data/train/COCO_train2014_000000018691.jpg': ['a few people sit on a dim transportation system',
#   'six people on a bus at night time',
#   'random people sitting in a public tranport bus',
#   'there are only a few people in the bus',
#   'a group of people are riding the bus'],
#  '/data/train/COCO_train2014_000000285579.jpg': ['a person protected from the rain by their umbrella walks down the road',
#   'a person walking outside in the rain with a green umbrella',
#   'a student walks in the rain with a green umbrella',
#   'an individual covers himself under an umbrella on a rainy day',
#   'a man walking in the rain crossing a street while holding an umbrella'],
#  '/data/train/COCO_train2014_000000266366.jpg': ['the bathroom with a toilet has an interesting sink',
#   'a demonstration of a well maintained hotel bathroom',
#   'a clean mediocre motel bathroom with a nice sink',
#   'a modern hotel bathroom with accessories set out',
#   'a bathroom with a toilet sink mirror and shower stall'],
#  '/data/train/COCO_train2014_000000226658.jpg': ['two women preparing food in a kitchen one at the sink and one at the table',
#   'a set table with silverware glasses and a bottle of wine',
#   'a woman having a slice of bread with jelly',
#   'a woman sitting at a table with win and bread',
#   'a women who is tearing off a piece of bread'],
#  '/data/train/COCO_train2014_000000124567.jpg': ['a cat stuck in a car with a slightly opened window',
#   'a cat peeking out a car window that is rolled down',
#   'a cat standing on a car seat looking out the car window',
#   'a person is taking a photo of a cat in a car',
#   'a cat sitting on top of the passenger seat of a car'],
#  '/data/train/COCO_train2014_000000293605.jpg': ['two bicycles and a woman walking in front of a shop',
#   'a woman walks by a couple of shop windows',
#   'woman walking down the street past a wig shop',
#   'a storefront with two bicycles and a woman walking past',
#   'a woman passing a store front wearing a long blue coat'],
#  '/data/train/COCO_train2014_000000321194.jpg': ['green tiled backsplash highlighted by low overhead lighting',
#   'a kitchen counter is illuminated by a hood light',
#   'a kitchen sink next to an empty counter with a tiled wall',
#   'a back splash is added to the wall in the kitchen',
#   'a picture of a sink top with dim lighting'],
#  '/data/train/COCO_train2014_000000479495.jpg': ['a bicycle is parked by a bench at night',
#   'a bike on the platform of a public transportation stop at night',
#   'a bicycle leans on a bench at a subway stop',
#   'a bicycle parked next to a bench in a train station',
#   'a bike and a bench on the side of a street'],
#  '/data/train/COCO_train2014_000000539984.jpg': ['a brown horse is grazing grass near a red house',
#   'a skinny horse is grazing in a field',
#   'a large hours is eating grass in a field',
#   'a brown horse is grazing in the grass',
#   'a brown horse grazes in an open field next to trees'],
#  '/data/train/COCO_train2014_000000028231.jpg': ['a black car is near someone riding a bike',
#   'a person on a bicycle is riding in front of a car',
#   'a blurry bike rider zooms past a new mercedes',
#   'a blurry bicycle riders goes by a black car',
#   'a man rides a bike past a black car in a parking lot'],
#  '/data/train/COCO_train2014_000000350235.jpg': ['this is a pickup game of shirts and skins basketball',
#   'a group of people playing a game of basketball',
#   'a group of men standing around while one seems angry at the others',
#   'several athletes appear to be having a disagreement',
#   'a man attempts to separate men during a fight at a street basketball game'],
#  '/data/train/COCO_train2014_000000314265.jpg': ['a toilet sink bathtub with shower mirror and cabinet',
#   'a small bathroom painted white with an empty shower',
#   'white bathroom with glass shelves and wood sink',
#   'a bathroom with an over the toilet cabinet',
#   'in the bathroom there is a shower sink and toilet'],
#  '/data/train/COCO_train2014_000000389006.jpg': ['a kitchen with a countertop that includes an apple phone',
#   'a phone and a computer on a kitchen counter',
#   'a phone lies on the counter in a modern kitchen',
#   'a nicely decorated kitchen with metallic refrigerator and blue counter',
#   'a clean kitchen with a phone and laptop on the counter'],
#  '/data/train/COCO_train2014_000000031813.jpg': ['a surfer riding his bike to the beach',
#   'a surfer rides his bike down the street',
#   'a man riding a bicycle on a road carrying a surf board',
#   'a man on a bike carrying a surfboard under his arm',
#   'a man rides a bike down the street while holding a surfboard'],
#  '/data/train/COCO_train2014_000000465049.jpg': ['a closeup of a red fire hydrant including the chains',
#   'a fire hydrant with chains is painted red',
#   'a red fire hydrant wrapped in a red chain on a sidewalk',
#   'the chain of a red fire hydrant is the focus',
#   'a fire hydrant and the chain attached to it'],
#  '/data/train/COCO_train2014_000000360334.jpg': ['a man standing in the kitchen with his arms crossed',
#   'young man with folded arms standing in the kitchen',
#   'a man standing in a white kitchen with his arms folded',
#   'a man folds his arms in a kitchen',
#   'man standing in a kitchen with his arms crossed'],
#  '/data/train/COCO_train2014_000000524679.jpg': ['a purple bus and a man dressed as a nun on a tall bicycle',
#   'sister on her bike trying to race the bus',
#   'a person riding a very high bike on the road',
#   'a nun riding a very tallk bike next to a purple bus',
#   'a woman in a nun costume is riding a bike next to a bus'],
#  '/data/train/COCO_train2014_000000279672.jpg': ['an herb that is in front of a toaster oven',
#   'a vegetable in front of a toaster oven',
#   'an evergreen sprig is sitting on top of an appliance',
#   'a microwave is next to sage or some kind of spice',
#   'this is a toaster with a green stem from a tree in front of it'],
#  '/data/train/COCO_train2014_000000385716.jpg': ['lady carrying a purse walking along side a man',
#   'a city sidewalk is lined with lamp posts',
#   'a man and a woman stand on the sidewalk lined with street lights',
#   'a city sidewalk with storefronts on the right',
#   'two people leaving a building to walk down the street'],
#  '/data/train/COCO_train2014_000000044816.jpg': ['clean bathroom that is brightly colored and has a window',
#   'a toilet sits next to a sink in a bathroom',
#   'a pristine bathroom sits waiting to be used',
#   'an empty bathroom painted yellow with an open window',
#   'this is a photo of a small hotel bathroom'],
#  '/data/train/COCO_train2014_000000360306.jpg': ['a man working at a kitchen counter in a room illuminated by sunlight',
#   'a man in shorts standing at the kitchen sink',
#   'a man is washing dishes in the kitchen sink',
#   'a man standing in a kitchen with a baby and dog',
#   'a man in a kitchen with his family in a house'],
#  '/data/train/COCO_train2014_000000122802.jpg': ['a man standing in a kitchen with granite countertops',
#   'an old man in the middle of his kitchen',
#   'a man stands in the middle of his granite countertopped kitchen',
#   'a man leaning forward on a counter top',
#   'a man stands behind a granite kitchen countertop with industrial lighting overhead'],
#  '/data/train/COCO_train2014_000000515040.jpg': ['seagulls flying overhead while trucks sit in a parking lot',
#   'a seagull perches on top of a van',
#   'a white van parked out side of a large white building',
#   'a white van sits outside of a white building',
#   'a white van parked with a seagull standing on top of it',
#   'single seagull sits on a white van with others flying in background'],
#  '/data/train/COCO_train2014_000000161657.jpg': ['a modern bathroom contains many glass and tile pieces',
#   'a bathroom with a white toilet and a white bath',
#   'the overhead view of a tiled bathroom with a tub shower toilet bidet and sink',
#   'a bathroom dimly lit with a bathtub and a shower',
#   'a bathroom with bathtub shower bidet toilet and sink'],
#  '/data/train/COCO_train2014_000000072704.jpg': ['a black cat making an angry face while sitting on the bathroom floor',
#   'a black cat sits next to laundry on the floor',
#   'a black cat sitting next to dirty clothes on the bathroom floor',
#   'a black cat sits on a bathroom floor next to some laundry',
#   'a cat sitting on a bath rug next to a pile of clothes'],
#  '/data/train/COCO_train2014_000000028149.jpg': ['a bathroom with a tv near the mirror',
#   'a television reflected off a mirror near a counter top',
#   'a flat screen tv sits next to a box of tissues and a remote control',
#   'a tv is behind glass in a bathroom',
#   'a hotel bathroom that has technology in the mirror'],
#  '/data/train/COCO_train2014_000000257263.jpg': ['a public restroom toilet has been photographed in sepia',
#   'a restroom with the toilet in the corner',
#   'a toilet is equipped with support bars for the disabled',
#   'a bathroom toilet is surrounded with silver handrails',
#   'toilet paper on the floor below a public toilet'],
#  '/data/train/COCO_train2014_000000520049.jpg': ['photo of a man riding an old styled bicycle near what appears to be the golden gate bridge',
#   'a man rides a bicycle across the river',
#   'man riding on a very old version of a personal bicycle',
#   'a man on an oldfashioned bicycle biking across a bridge',
#   'a man in a yellow coat rides an oldfashioned bicycle'],
#  '/data/train/COCO_train2014_000000503598.jpg': ['there is some pet food in the floor in an empty kitchen',
#   'a kitchen sink counter pots and a dog dish',
#   'there is a small kitchen with wooden cabinets and pet bowls on the floor',
#   'a kitchen with a pets food dishes on the floor',
#   'a very clean kitchen with some animal food on the ground'],
#  '/data/train/COCO_train2014_000000230843.jpg': ['a young boy surfing in low waves',
#   'a young boy is standing on a surfboard and riding a wave',
#   'a surfer rides his surf board on some very small waves',
#   'a young boy is standing on a surfboard in the water',
#   'a young boy is standing on a surfboard in the ocean'],
#  '/data/train/COCO_train2014_000000231029.jpg': ['the top of a kitchen cabinet covered with brass pots and pans',
#   'a kitchen with some old fashioned kitchen ware',
#   'a kitchen with copper pots on pot racks and on the stove',
#   'a restaurant kitchen with bowls and pans ready for the night',
#   'a kitchen with several brass pots and pans on stove tops'],
#  '/data/train/COCO_train2014_000000174028.jpg': ['a woman is shaving her face while sitting on a wooden bench',
#   'two girls sitting on a bench eating lunch',
#   'a girl demonstrating the act of shaving sitting on a bench',
#   'a girl trusts another girl to shave her while sitting back to back',
#   'two females sitting on a bench one is being the arms for the other'],
#  '/data/train/COCO_train2014_000000480489.jpg': ['the sky is full of colorful kites along a mountain',
#   'a large kite in the shape of the bottom half of a woman',
#   'the parachutes fly through the sky next to each other',
#   'assorted decorations laying around on a plastic tarp',
#   'a plethora of kites flying in the sky next to some mountains'],
#  '/data/train/COCO_train2014_000000056972.jpg': ['a bathroom in white has a cupboard above the sink',
#   'a bathroom sink and cabinet featuring everything white',
#   'a bathroom with a sink cabinet mirror and picture',
#   'a white pedestal sink below a white cabinet in a white bathroom',
#   'a modern bathroom sink and wall deco is shown'],
#  '/data/train/COCO_train2014_000000187042.jpg': ['a bike and a raft sit atop a boat on the water',
#   'a boat in the water with a raft and a bike loaded at one end of it',
#   'a boat has a raft and a bicycle on it',
#   'the front of a boat with a raft and bicycle on it',
#   'a small boat with a raft and bike strapped to it in a body of water'],
#  '/data/train/COCO_train2014_000000101891.jpg': ['bicycles cars and a trash can in a garage',
#   'clutter blocks antique cars from leaving the garage',
#   'a garage filled with old cards and old bicycles',
#   'some antique cars sit in a garage with some bicycles',
#   'a garage with bicycles cars and a garbage can'],
#  '/data/train/COCO_train2014_000000090359.jpg': ['a man jumping his bicycle onto a bench',
#   'a man balancing a bike on a bench',
#   'a man does a trick on a bike on a bench',
#   'a young man rides his bicycle on top of a cement bench',
#   'a man on a bicycle performing tricks on a bench'],
#  '/data/train/COCO_train2014_000000213532.jpg': ['black and white image of two children paying attention',
#   'a boy holding his arm around the shoulders of the girl sitting next to him',
#   'a boy places his arm around a friend',
#   'one kid has his arm wrapped around the other kid',
#   'two children sitting down one with his arm over the other'],
#  '/data/train/COCO_train2014_000000024091.jpg': ['a compact car with bicycles mounted on the roof',
#   'a car with a bunch of bicycles strapped to its roof',
#   'a car with several bikes on a bike rack',
#   'a car is loaded down with many bicycles attached to its roof',
#   'a car has multiple bikes hooked onto its roof'],
#  '/data/train/COCO_train2014_000000372427.jpg': ['a crisp neutral bathroom embellished with modern treatments',
#   'the toilet is next to a curtained window',
#   'curtains hanging in a bathroom window beside a toilet',
#   'a bathroom window reveals a snowy day outside',
#   'a tan bathroom with black curtains and towel'],
#  '/data/train/COCO_train2014_000000376047.jpg': ['a kitchen scene with stainless steel appliance and a checkered pattern floor',
#   'a kitchen with new age appliances and equipment',
#   'silver and white colored personal kitchen with yellow tiling',
#   'a modern lighted kitchen with stainless steel appliances',
#   'a picture of some appliances stove dishwasher refridgerator and microwave in a kitchen'],
#  '/data/train/COCO_train2014_000000577876.jpg': ['a lady talking a self portrait in a fancy bathroom',
#   'a woman takes a selfie in front of a restroom mirror',
#   'a woman takes a photo of her reflection in a bathroom mirror',
#   'a woman takes her picture in the mirror in the bathroom',
#   'a woman taking a self shot at an ornate mirror and sink'],
#  '/data/train/COCO_train2014_000000047093.jpg': ['a woman walking and talking on a cell phone',
#   'a female student is talking on her phone while walking',
#   'a young woman walking down the street while talking on her cell phone',
#   'two young women walking while one is on a cell phone',
#   'two young woman walking by a fire hydrant one talking on cell'],
#  '/data/train/COCO_train2014_000000374873.jpg': ['a man on top of a snowy mountain with skis',
#   'a group of skiers stand atop a snowy peak',
#   'group of skiers atop a mountain looking over edge',
#   'a man poses for a picture on top of a snowy hill',
#   'skiers are standing at the top of a snowcovered mountain'],
#  '/data/train/COCO_train2014_000000360053.jpg': ['a stuffed animal is laying on the bed by a window',
#   'a white bear laying on a bed with someones hand on the other side',
#   'a white teddy bear is laying on a bed in a dimly lit room',
#   'a teddy bear lying face down on a bedspread covered mattress in front of a window',
#   'a bed with blue bed spread on it in front of a window'],
#  '/data/train/COCO_train2014_000000517565.jpg': ['a wooden toilet seat sits open in an empty bathroom',
#   'a bathroom with a sink shower and toilette',
#   'a bathroom with a toilet and a sink',
#   'bathroom shot of an open toilet and sink',
#   'an empty bathroom with the toilet seat up'],
#  '/data/train/COCO_train2014_000000543882.jpg': ['a decorated table covered with plates of food and vegetables',
#   'a buffet of different types of food sitting on a buffet table',
#   'a buffet table at a restaurant covered with food',
#   'the two banquet tables held a variety of meats dips and pastries',
#   'a display of many prepared food dishes arranged decoratively on serving table'],
#  '/data/train/COCO_train2014_000000038682.jpg': ['a picture of a man riding a bicycle at night',
#   'a man with a backpack rides a bicycle',
#   'a man using his bicycle to go down a street',
#   'a person with a backpack on riding by on a bike',
#   'a man riding a bike down the street at night'],
#  '/data/train/COCO_train2014_000000568117.jpg': ['thee cats sleeping on a bed with a person',
#   'three cats sleeping with their owners on a bed',
#   'three cats are sleeping on a bed with a person',
#   'a person is sleeping on the same bed as three cats',
#   'two black cats nap as a white cat lays on a sleeping persons chest'],
#  '/data/train/COCO_train2014_000000186620.jpg': ['a young man playing a game of frisbee',
#   'a man extends his hand out to catch a frisbee',
#   'a man in a courtyard reaches out to catch a frisbee',
#   'college student playing frisbee on a campus lawn',
#   'a man has a frisbee in mid air just out of his hand'],
#  '/data/train/COCO_train2014_000000004377.jpg': ['a group of people playing a game of croquet',
#   'a game of croquet is being played in a back yard',
#   'two guys and a girl playing croquet in the yard',
#   'a group of four people playing croquet on a lawn',
#   'a group of friends enjoy a game of croquet on a grassy fenced in field'],
#  '/data/train/COCO_train2014_000000189278.jpg': ['a chef opens up an oven in a kitchen',
#   'this is a restaurant kitchen with two industrial ovens',
#   'there are two ovens in a kitchen restaurant and one of them is being used',
#   'two ovens in use in a professional kitchen',
#   'a person standing in a kitchen next to an oven'],
#  '/data/train/COCO_train2014_000000170045.jpg': ['a woman standing beside a clean kitchen island',
#   'a woman standing behind the island in the kitchen',
#   'a woman making something in a kitchen',
#   'a woman stands in the kitchen surrounded by wood cabinets and stainless steel appliances',
#   'a woman is standing at the island counter in a kitchen'],
#  '/data/train/COCO_train2014_000000416172.jpg': ['a kitchen being prepared to get newly painted',
#   'the corner of an empty kitchen with cleaning products all over the counter',
#   'dirty kitchen with cleaning supplies placed allover the counters',
#   'an a kitchen is being cleaned and decluttered',
#   'a dirty kitchen that looks to be under construction'],
#  '/data/train/COCO_train2014_000000309517.jpg': ['a person standing in front of a large body of water as the sun sets',
#   'the silhouette of a person standing in front of a sunset over water',
#   'a person is standing in front of the ocean at sunset',
#   'a dark profile of a person set before a sunset on the beach',
#   'man standing like a shadow in front of the ocean'],
#  '/data/train/COCO_train2014_000000274682.jpg': ['an empty bathroom with a large mirror and sink',
#   'a bathroom with two sinks and a closet',
#   'a white bathroom with a walk in closet is shown',
#   'a bathroom under construction with a double sink vanity that has a mirrir and light strip over it',
#   'a master bedroom with a closet and attached bathroom'],
#  '/data/train/COCO_train2014_000000480545.jpg': ['a set of stairs lead to a toilet and cabinet in a bathroom',
#   'the bathroom door next to the laundry room is open',
#   'through the door view of a small white bathroom',
#   'a small bathroom containing a step toilette and sink',
#   'the bathroom has a toilet sink tile floor and wooden panels on the outside'],
#  '/data/train/COCO_train2014_000000210082.jpg': ['double doors open into a bathroom with a footed tub',
#   'a freestanding bathroom near an open door and table',
#   'a bathroom scene with open double doors double sinks and a bathtub',
#   'a bathroom with the door open and a tub',
#   'there is an asian inspired bathroom with double doors'],
#  '/data/train/COCO_train2014_000000474031.jpg': ['an empty kitchen has walls painted white',
#   'a kitchen area with a microwave and refrigerator',
#   'a house with a white decorated kitchen',
#   'a large kitchen featuring a counter top and refrigerator',
#   'a large kitchen decorated with white flowers and books'],
#  '/data/train/COCO_train2014_000000429065.jpg': ['a colorful tent is stationed on a bike lane',
#   'a biker rides through a tent in a bike lane',
#   'a multicolored kiosk for cyclists in a city',
#   'colorful tent on a street is a stop for bicyclists',
#   'a shelter area for people on bicycles to warm up from the cold'],
#  '/data/train/COCO_train2014_000000002448.jpg': ['two kitchen stools sitting in front of an island in a kitchen',
#   'a kitchen counter with chairs refrigerator and cupboards',
#   'a picture of a kitchen area with refrigerator and stove',
#   'a kitchen with a refrigerator oven and counter',
#   'a very clean kitchen with the light on'],
#  '/data/train/COCO_train2014_000000161749.jpg': ['two dogs stand in a kitchen beneath their owner',
#   'two stands standing on the floor by their owners legs',
#   'two dogs with a woman in the kitchen',
#   'a photo on a kitchen floor with a persons legs and two dogs',
#   'person standing in the kitchen with two dogs at their feet'],
#  '/data/train/COCO_train2014_000000435091.jpg': ['a woman smiles at a man who is wearing a colorful sarong',
#   'man and woman with group of scissors on table',
#   'a shirtless man wearing a pink towel in the kitchen with a woman drinking wine',
#   'man dressed in a wrap in a personal kitchen',
#   'a man in a pink sarong showing scissors to a woman with wine'],
#  '/data/train/COCO_train2014_000000385626.jpg': ['woman riding a bicycle down an empty street',
#   'a woman in green is riding a bike',
#   'a woman wearing a bright green sweater riding a bicycle',
#   'a woman on a bicycle is going down the small town street',
#   'a woman bikes down a one way street'],
#  '/data/train/COCO_train2014_000000180141.jpg': ['a family sits at a table together enjoying each others company',
#   'a family is playing a karaoke video game',
#   'a family watches while two boys play a singing game',
#   'a family watches two boys singing into microphones',
#   'kids and their moms are singing karaoke at the table'],
#  '/data/train/COCO_train2014_000000330238.jpg': ['a crowd of skiers prepare to ski down snow covered slopes',
#   'many skiiers are gathered at the base of a hill while several travel down it',
#   'hikers climb up a snowcovered mountain in the winter',
#   'skiers of all ages skiing down a slope and gathering at the bottom',
#   'a group of people are skiing on a mountain'],
#  '/data/train/COCO_train2014_000000499237.jpg': ['towels are neatly stacked on a shelf in the bathroom',
#   'a table with towels on top of it placed under a mirror',
#   'a bathroom vanity with towels folded under the sink',
#   'a pedestal sink with vanity sits below a mirror',
#   'towels stored under a bathroom sink with a glass countertop'],
#  '/data/train/COCO_train2014_000000466800.jpg': ['a view of a fancy spa like bathroom with a blue tiled tub',
#   'different types of tiles are on the walls floor and tub',
#   'large modern bathroom with jacuzzi in a house',
#   'a modern bathtub in a bathroom is displayed',
#   'a nice bathroom with a standalone shower and a shower curtain'],
#  '/data/train/COCO_train2014_000000279939.jpg': ['a bathroom contains a toilet sink and bathtub',
#   'the white bathroom has orange blue and gray accents',
#   'a small bathroom with a white toilette and bath tub',
#   'a bathroom with toilet and bowl for sink',
#   'a bathroom with a toilet sink and bathtub'],
#  '/data/train/COCO_train2014_000000526165.jpg': ['loving couple pose together behind a fruitadorned cake',
#   'an older woman preparing to blow out the candle on her birthday cake standing besides an older man',
#   'a married couple posing in front of a piece of birthday cake',
#   'a man and woman smiling in front of a cake',
#   'a man and woman celebrating a special occasion about to blow out a candle'],
#  '/data/train/COCO_train2014_000000334790.jpg': ['a young man jumping his skate board over a cement seating area',
#   'boy riding skateboard and doing trick in air',
#   'a man in a blue shirt and jeans doing a trick on a skateboard',
#   'a skateboarder is airborne as he does a trick',
#   'a young man performing a trick on a skateboard'],
#  '/data/train/COCO_train2014_000000014750.jpg': ['a bicycle with a basket is parked at the side of a building',
#   'a bicycle leaning against a building near a window',
#   'a bicycle parked against the side of a stone house',
#   'a bicycle leaning against an old white building',
#   'a bicycle is parked up against a white stucco building'],
#  '/data/train/COCO_train2014_000000573518.jpg': ['a black colored keyboard for a computer system',
#   'a black computer keyboard with lcd panel and numeric pad',
#   'a wireless keyboard compatible with role playing games',
#   'a computer keyboard with black keys and white lettering',
#   'a black computer keyboard with a bunch of keys on it'],
#  '/data/train/COCO_train2014_000000253464.jpg': ['a mid sized bathroom with toilette shower and vanity mirror above a sink',
#   'a very clean bathroom with the lights on',
#   'the yellow flowers sits atop the counter in a clean bathroom',
#   'a very clean bathroom is shown with wood cabinets',
#   'a bathroom has a green and white striped shower curtain'],
#  '/data/train/COCO_train2014_000000291827.jpg': ['two boys with surf boards walking out into the ocean',
#   'surfers waiting for the right wave to ride',
#   'guys on their way to surfboard at the beach',
#   'people with surf boards going into the ocean',
#   'a group of surfers wade into the sea'],
#  '/data/train/COCO_train2014_000000478007.jpg': ['a bathroom sink and counter with a large mirror above it',
#   'a wood bathroom vanity with a granite countertop',
#   'this is a bathroom sink in a hotel',
#   'an indoor bathroom with reflective marble counter tops',
#   'a hotel room bathroom sink and tissue dispenser'],
#  '/data/train/COCO_train2014_000000461221.jpg': ['a kitchen with a over stove and toaster oven including a microwave',
#   'a kitchen with sink stove and a white cabinet',
#   'a kitchen cupboard in a kitchen with a stove and a sink',
#   'a large kitchen cabinet or pantry in a small kitchen',
#   'small clean kitchen with a large white cupboard'],
#  '/data/train/COCO_train2014_000000416909.jpg': ['an un occupied bathroom with a shower toilette and sink',
#   'a clean bathroom with sink toilet and shower',
#   'a small bathroom showing the sink and toilet area',
#   'a door leading to a bathroom with a sink visible',
#   'a door opening to a bathroom with orange shades and matching rug'],
#  '/data/train/COCO_train2014_000000377955.jpg': ['a silver car parked in a shopping center parking lot',
#   'a car is parked in a empty parking lot',
#   'the shopping plaza has many stores and one parked car',
#   'a silver sedan is parked in a plaza lot on a cloudy day',
#   'a small strip mall with a few cars in the parking lot'],
#  '/data/train/COCO_train2014_000000550126.jpg': ['a bathroom with a close shower curtain next to a toilette',
#   'a white shower curtain with a spiral pattern hanging in the bathroom',
#   'a bathroom with a toilet bowl and shower curtain',
#   'a bathroom has a large shower curtain with design',
#   'a closed shower curtain in a tiled bathroom'],
#  '/data/train/COCO_train2014_000000194698.jpg': ['a small dog cradled in his loving owners arm as he falls asleep',
#   'a person holding a chihuahua sleeping on its back in their arm',
#   'a person holding a small sleeping dog in their arms',
#   'a little dog is laying on a mans arm',
#   'a small dog taking a nap on the arm of a person'],
#  '/data/train/COCO_train2014_000000579846.jpg': ['a nearly empty house with a bicycle mounted on the wall',
#   'a hall opening onto a bathroom bedroom and two other rooms',
#   'a view of a hallway in a house',
#   'there is a hallway leading to a door where bicycle tires are showing',
#   'a house hallway with all the bedroom doors open'],
#  '/data/train/COCO_train2014_000000009469.jpg': ['a teenage boy is in a field looking at a wire',
#   'the boy is inspecting the wire for a project',
#   'a young guy checking on a wire as he holds onto a dog leash',
#   'a boy is outside with his dog in a field surrounded by a sign and other items',
#   'a boy building something with wires and poles'],
#  '/data/train/COCO_train2014_000000348595.jpg': ['a man in a parade has red and white face and umbrella',
#   'a young person with red and white face paint holds an umbrella',
#   'soccer fan is showing his support by dressing up',
#   'a man with a painted red and white face is standing in the street',
#   'a person with their face painted standing in the street'],
#  '/data/train/COCO_train2014_000000079143.jpg': ['a small bathroom has separate tub and shower',
#   'a spacious bathroom with a fancy bathtub and sink',
#   'a bathroom is lit by a light over a sink',
#   'a light is on in an empty clean bathroom',
#   'a shiny bathroom has an old fashioned bathtub and gold walls'],
#  '/data/train/COCO_train2014_000000346909.jpg': ['two dogs are laying down next to each other',
#   'two dogs were captured in a photo with the lighting of the image altered',
#   'two dogs sitting one the ground looking at something',
#   'two dogs are resting together on the floor',
#   'two doge have their paws out in an overexposed picture'],
#  '/data/train/COCO_train2014_000000351191.jpg': ['a woman crossing a city street while carrying groceries',
#   'shopper crossing a street in the downtown of a city',
#   'a person crossing at a crosswalk with bags in his hands',
#   'a city street scene with cars and a person crossing the street',
#   'a man is crossing a city intersection carrying bags'],
#  '/data/train/COCO_train2014_000000165350.jpg': ['a group of bike riders race down a busy street',
#   'a group of bikers round a turn on a road',
#   'cyclists competing in a race round a corner',
#   'a peleton of cyclists leaning into a turn',
#   'multiple cyclists riding their bikes on the street'],
#  '/data/train/COCO_train2014_000000549575.jpg': ['a kitchen filled with many cupboards and lots of counter space',
#   'an empty and very clean white and tan kitchen',
#   'unused kitchen stove sink and counter topsand cabinettes',
#   'a clean kitchen that is empty and white',
#   'an unfurnished kitchen in a tropical house hold'],
#  '/data/train/COCO_train2014_000000387408.jpg': ['an attractive woman taking a selfie in a bathroom',
#   'a selfie of a young woman in her bathroom',
#   'a woman is taking a picture of herself in the bathroom',
#   'a woman taking a selfie in a bathroom',
#   'a woman taking a photo of herself in the mirror'],
#  '/data/train/COCO_train2014_000000331863.jpg': ['a group of people sitting on a couch while a brown dog looks at them',
#   'a group of friends spending the day watching tv together',
#   'four friends lounge on a couch with a dog',
#   'a dog sits staring at a group of people',
#   'a group of people who are sitting together on a couch'],
#  '/data/train/COCO_train2014_000000350553.jpg': ['an older woman walking a bicycle with a bus in the background',
#   'a woman walks her bike past a city bus',
#   'a lady waking a bike by a bus',
#   'a woman walks her bicycle near a bus',
#   'a woman walking a bike while a bus passes by'],
#  '/data/train/COCO_train2014_000000064941.jpg': ['three people riding bikes on the side of a road',
#   'a group of two adults and a child biking down a road',
#   'two adults and a child riding bicycles on the side of a road',
#   'a couple and their child riding bikes down an asphalt road',
#   'a young family is biking in the bike lane of a road'],
#  '/data/train/COCO_train2014_000000219409.jpg': ['a fridge that is halfway open during the night',
#   'an open refrigerator in a kitchen next to a cupboard',
#   'a fridge door is open in a kitchen at night',
#   'an open refrigerator with a shinning bright light',
#   'lower door of refrigerator open in dark kitchen'],
#  '/data/train/COCO_train2014_000000471895.jpg': ['a bathroom featuring an oddly shaped toilette shower and sink',
#   'a small bathroom decorated with pretty red flowers',
#   'a bathroom with a toilet sink and a mirror',
#   'the bathroom has a shower area toilet and sink',
#   'a bathroom that has some flowers on the sink and toilet'],
#  '/data/train/COCO_train2014_000000425135.jpg': ['the inside of a bathroom with two sinks',
#   'a large bathroom with two sinks and three windows',
#   'a view of a communal bathroom with multiple sinks and windows',
#   'a bathroom with two porcelain sinks and hexagonal tiles',
#   'a bathroom with two sinks a bathtub and a shower with lots of lighting from the windows'],
#  '/data/train/COCO_train2014_000000175565.jpg': ['a cocker spaniel sitting next to a woman holding a baby',
#   'a dog lays on a couch next to a woman holding a baby',
#   'a dog is laying next to a woman holding a baby',
#   'a person sitting in a chair holding a baby and a dog',
#   'a woman holding a baby and sitting next to a dog'],
#  '/data/train/COCO_train2014_000000178771.jpg': ['a man on his skateboard at a basketball court',
#   'a young boy riding a skate board at a public skate park',
#   'a person skateboarding on an outside basketball court',
#   'a boy is doing tricks on his skateboard',
#   'a skateboarder has one end of the board in the air on top of a bench'],
#  '/data/train/COCO_train2014_000000432201.jpg': ['clean stainless steel kitchen with large cabinets and counter',
#   'a small spotless and clean stainless steel kitchen',
#   'a stainless steele kitchen with sinks and lots of storage',
#   'a restaurant kitchen stocked with stainless steel appliances',
#   'a kitchen with a sink ovens and dishes in it'],
#  '/data/train/COCO_train2014_000000051644.jpg': ['a srfer perches on his board precariously as he hits a big wave',
#   'a man riding a wave with a surfboard',
#   'a surfer catches a wave but is about to fall off his board',
#   'a man is surfing on some small ocean waves',
#   'a man on a surf board rides on some waves'],
#  '/data/train/COCO_train2014_000000565401.jpg': ['a bicycle leans against a park bench with a flowering tree nearby',
#   'a bicycle parked in the grass by a tree',
#   'a bicycle leaning up against a park bench',
#   'a bicycle leans on a bench in a park',
#   'the bicycle is parked beside of the bench outside'],
#  '/data/train/COCO_train2014_000000256950.jpg': ['the serving counter of a restaurant is quiet',
#   'a kitchen filled with dishes and bowls stacked on top of each other',
#   'kitchen ware sitting behind the counter top at a restaurant',
#   'the restaurant kitchen is highly lit displaying the colorful bowls',
#   'there are various utensils on the counter of a large kitchen'],
#  '/data/train/COCO_train2014_000000276961.jpg': ['a bathroom mirror with items in front of it',
#   'a mirror reflecting the opposite wall of a bathroom',
#   'a view of a mirror in a bathroom',
#   'a tiled bathroom vanity with a small mirror',
#   'a tiled bathroom with toothbrushes and shaving accessories'],
#  '/data/train/COCO_train2014_000000530832.jpg': ['two women prepare a meal in a large kitchen',
#   'two woman standing in a kitchen preparing food',
#   'two women working in a large kitchen with natural lighting',
#   'a wide angle view of a kitchen with two women working',
#   'two women in the kitchen standing by the sink'],
#  '/data/train/COCO_train2014_000000211265.jpg': ['an empty bathroom featuring a toilette and window',
#   'a bathroom toilet next to a window with a handicap bar next to it and a cabinet over it',
#   'a white bathroom with a tan toilet and a hand rail',
#   'a toilet bowl with a handicap rail next to it',
#   'the sunlight is shining brightly in the bathroom'],
#  '/data/train/COCO_train2014_000000226517.jpg': ['a kitchen with a wooden kitchen table and appliances in it',
#   'a kitchen has a wooden table and capinets',
#   'a kitchen scene with a dining room table and chairs',
#   'a kitchen with wooden drawers table chairs and stone counter tops',
#   'a kitchen with a table and chairs and various kitchen appliances'],
#  '/data/train/COCO_train2014_000000209040.jpg': ['a bathroom sink with mirror placed above it',
#   'a nice bathroom has a clean counter with makeup toothbrushes',
#   'a bathroom scene looking at the sink and mirror',
#   'a white background with white counter top and white walls',
#   'a bathroom with a sink and a mirror'],
#  '/data/train/COCO_train2014_000000199743.jpg': ['a person on a bicycle waiting to cross a street at the intersection',
#   'a man on a bike waiting at a crosswalk',
#   'a man waits at the crosswalk with his bicycle',
#   'a bicyclist and cars wait at a busy intersection',
#   'a person on a bicycle at a cross walk'],
#  '/data/train/COCO_train2014_000000427180.jpg': ['a woman in a fushia shirt cooking in an industrial kitchen',
#   'a man preparing food in a kitchen underneath a clock',
#   'a person in a commercial kitchen preparing food',
#   'two large refrigerators and long workstation indicate a commercial kitchen',
#   'a person working alone in a large kitchen'],
#  '/data/train/COCO_train2014_000000416565.jpg': ['a small wood paneled bathroom with a sink mirror and toilette',
#   'a bathroom with wooden wall panelling and white sink and toilet',
#   'a bathroom has walls made of wooden planks',
#   'a small bathroom has four identical wooden walls',
#   'wood panaled bathroom with sink mirror and a toilet'],
#  '/data/train/COCO_train2014_000000375878.jpg': ['a pink tub and sink in a white bathroom',
#   'a bathroom that is very clean and nice',
#   'a white bathroom with a matching pink sink and bathing tub',
#   'a fresh airy white and pink clean bathroom',
#   'a white bathroom has a pink tub and sink'],
#  '/data/train/COCO_train2014_000000233201.jpg': ['an empty bathroom with a sink and mirror next to a toilette',
#   'an empty bathroom with a very clean sink',
#   'a small bathroom has a small sink and window',
#   'a bathroom with a sink and red curtains',
#   'a bathroom sink next to a wooden cabinet'],
#  '/data/train/COCO_train2014_000000360871.jpg': ['a kitchen filled with appliances and cupboards green painted walls',
#   'an assortment of vegetables sitting on the kitchen counter',
#   'a kitchen with a microwave refrigerator and sink',
#   'a view of a kitchen with vegetables on the counter and a white fridge',
#   'a white kitchen has green and lime accents'],
#  '/data/train/COCO_train2014_000000014698.jpg': ['a beautiful blonde woman rides a skateboard across a busy street',
#   'a biker and a skateboarder ride across the road in front of cars',
#   'a teenage girl on a skateboard glides down an urban street following a cyclist',
#   'a young woman riding a skateboard down the road',
#   'a girl in a pink shirt is riding a skateboard across an intersection'],
#  '/data/train/COCO_train2014_000000376731.jpg': ['a lady in a large hat riding a bike',
#   'a woman with a sun hat riding a bicycle',
#   'a woman with a pointed hat riding a bicycle',
#   'asian woman riding her bike downtown with a little hat on her head',
#   'the woman is wearing a hat and riding her bike'],
#  '/data/train/COCO_train2014_000000063943.jpg': ['a black car traveling past parked cars on a tree filled street',
#   'a car is stopped in front of downed trees on the street',
#   'several cars approach a cone barrier on a suburban street',
#   'a street is blocked off with green tape',
#   'a street that has been blocked off and a tree is down covering the street'],
#  '/data/train/COCO_train2014_000000143358.jpg': ['a man wearing plate armor and metal helmet while talking on a cell phone',
#   'an asian man dressed in armor talking on a cell phone',
#   'a man in a knight costume on a cell phone',
#   'a man in japanese armor talking on a cell phone',
#   'a person dressing in a warrior costume on a cell phone'],
#  '/data/train/COCO_train2014_000000012876.jpg': ['a bicycle parked up against a rust covered filthy alley wall',
#   'a bicycle sitting on a ledge near a building',
#   'a bicycle parked against a dirty wall on a ledge',
#   'a bike with a basket leans against a rusty wall',
#   'a bicycle with a basket on the wall of a building'],
#  '/data/train/COCO_train2014_000000166130.jpg': ['a kitchen filled with appliances next to a hard wood floor',
#   'a picture of a kitchen that is very clean',
#   'a picture of a white kitchen with all appliances',
#   'a small with white appliances cupboards and floor',
#   'a kitchen has a beige refrigerator and oven'],
#  '/data/train/COCO_train2014_000000063512.jpg': ['a bathroom decorated with white frilly towels and accessories',
#   'a bathroom with white sheer toilet covers and curtains',
#   'bathroom pictures are seen decorated with frilly accessories',
#   'a bathroom is heavily decorated with lacy cloths',
#   'a bathroom with coverings on the toilet tank and lid'],
#  '/data/train/COCO_train2014_000000355651.jpg': ['a young man riding his skate board up a ramp',
#   'a skateboarder that is doing a trick on a ramp',
#   'a boy doing a skateboard trick on a ramp',
#   'a skateboarder on a wooden ramp in the middle of the street',
#   'person on skateboard at the top of ramp'],
#  '/data/train/COCO_train2014_000000399465.jpg': ['women walk by a person sitting on a public bench with a dog',
#   'guy reading with a dog on his lap',
#   'a man sits on a bench with a dog in lap reading',
#   'a person sitting on a park bench with their dog',
#   'two women walking on a sidewalk past a bench where a man sits with his dog'],
#  '/data/train/COCO_train2014_000000177467.jpg': ['a man with baskets of goods stands next to his bicycle',
#   'a man riding a bike carrying a large stack of beverages',
#   'man standing at his bike full of drink products',
#   'a man carting goods through a city on his bike',
#   'a man is on a bicycle loaded down with items'],
#  '/data/train/COCO_train2014_000000293374.jpg': ['a bathroom with tile floors and a walk in shower',
#   'a small bathroom with a small standup shower',
#   'scene of a bathroom up close shower and toilet',
#   'a bathroom with a toilet and a shower',
#   'the bathroom has towels hanging in the corner'],
#  '/data/train/COCO_train2014_000000398406.jpg': ['an older gentleman holding his hat standing alongside a car',
#   'an older white male standing in front a dump truck and beside a car',
#   'a man is standing with his hat in his hand next to a car',
#   'an older man standing next to an old fashioned car',
#   'man holding his hat standing next to a car'],
#  '/data/train/COCO_train2014_000000335385.jpg': ['a bathroom with a shower and his and her sinks',
#   'a bathroom that is very clean showing a door',
#   'a bathroom with dual sinks and a stand alone shower',
#   'a bathroom with a shower and a sink',
#   'the bathroom has a walltowall double sink with wood vanity and a shower stall'],
#  '/data/train/COCO_train2014_000000324809.jpg': ['a man holds a banana as if it were a telephone receiver',
#   'man pretending to talk into a banana as though it were a telephone',
#   'a man holding a banana to his ear like a telephone',
#   'a man holding a banana to his ear like a phone',
#   'a man holding a banana as if it were a phone'],
#  '/data/train/COCO_train2014_000000236294.jpg': ['an empty bathroom with a sink and toilette underneath a hand drying towel',
#   'a bathroom with a toilet and a shower',
#   'a clean bathroom with a big glass shower door',
#   'a bathroom that is primarily white and gray',
#   'a modern restroom that has an open shower with an opaque glass wall'],
#  '/data/train/COCO_train2014_000000306705.jpg': ['a couple of people prepare food while working in a kitchen',
#   'three people in a kitchen preparing a meal',
#   'an old couple cooking food in a kitchen',
#   'a kitchen is being used to cook for a family dinner',
#   'three people in a kitchen with the counter cluttered'],
#  '/data/train/COCO_train2014_000000261576.jpg': ['young woman in white dress brushing teeth over bathroom sink',
#   'a female is brushing their teeth using a toothbrush',
#   'a doll holds a cup of coffee and brushes her teeth',
#   'a woman brushing her teeth in front of a mirror',
#   'a girl brushing her teeth in the bathroom mirror'],
#  '/data/train/COCO_train2014_000000357656.jpg': ['a bathroom with a bathtub and a door made out of glass',
#   'light shines into a bathroom with toilet and shower',
#   'a small bathroom with a glass fronted shower tub combo',
#   'a shower in a bathroom with a glass door',
#   'a bathroom has a glass door on the shower and tub'],
#  '/data/train/COCO_train2014_000000292927.jpg': ['an open kitchen and living room in a daylit house',
#   'this is the kitchen and entryway of a house',
#   'a kitchen with a lot of clutter on the countertop',
#   'a modern kitchen in a new apartment with sparse furniture and moving boxes',
# ...
#   'a person riding a cycle on a street with a group of people nearby',
#   'a man with spiky hair is riding down a sidewalk while others look'],
#  '/data/train/COCO_train2014_000000066327.jpg': ['a clean kitchen with all wooden cabinetry in it',
#   'everything in the kitchen and dining area is made of wood',
#   'a kitchen with many wood cabinets and a wood table',
#   'open bar area inside a house made all of wood',
#   'a kitchen and dining room where everything is wood'],
#  '/data/train/COCO_train2014_000000573232.jpg': ['a bathroom door cracked open so you can see the toilet',
#   'a bathroom door is slightly open and the light is on',
#   'the slightly open door has a small bathroom in it',
#   'the bathroom door is ajar and the toilet and tiled floor are in view',
#   'a partially open door leading to a bathroom'],
#  '/data/train/COCO_train2014_000000046371.jpg': ['a man in a suit and tie wearing a hat',
#   'a man in a gray jacket and tie standing next to a street',
#   'the bearded man in the suit has on a hat',
#   'man in green suit jacket standing in front of a green building',
#   'a bearded man wearing a suit and tie'],
#  '/data/train/COCO_train2014_000000130598.jpg': ['a bathroom sink that has leaves on the bottom',
#   'a very nice modern bathroom with toitet sink and shower',
#   'a bathroom with many brown fixtures and brown floors',
#   'the bathroom has a shower toilet toilet paper and a sink with leaves in it',
#   'the small bathroom has a brown color to it'],
#  '/data/train/COCO_train2014_000000349263.jpg': ['a narrow kitchen with brown cabinets sink and refrigerator',
#   'pictures hang on a refrigerator in a kitchen',
#   'the refrigerator has magnets on the top of it',
#   'a kitchen scene with focus on the white refrigerator',
#   'small outdated residential kitchen showing sink and refrigerator'],
#  '/data/train/COCO_train2014_000000154927.jpg': ['a woman holding a digital camera in front of a mirror',
#   'a woman prepares to take a photograph in front of a mirror',
#   'a person taking a photo in a mirror',
#   'a person takes a photo of their reflection in the mirror',
#   'a woman taking a selfie in a mirror with a camera'],
#  '/data/train/COCO_train2014_000000296187.jpg': ['very open bathroom with a strange pattern on the floor',
#   'an empty bathroom with a toilet and sink',
#   'a bathroom filled with floor tiles in a wild pattern',
#   'a small bathroom has an interesting tile floor',
#   'a bathroom with interesting tile and a toilet'],
#  '/data/train/COCO_train2014_000000291466.jpg': ['a child is eating out of a cup with a spoon',
#   'a young child brushing their teeth holding a cup of water',
#   'a small child holds a cup of water in one hand while brushing his teeth with the other',
#   'a small child brushing her teeth from a cup',
#   'small child with blue toothbrush brushing his teeth'],
#  '/data/train/COCO_train2014_000000558697.jpg': ['several people stand next to a parked airplane where people are exiting the plane',
#   'a group of people disembarking from a plane at and airport',
#   'a plane that is on the ground in the nighttime',
#   'a dragonair plane awaiting boarding passengers at night',
#   'a huge chinese aircraft is sitting at an airport with people unloading'],
#  '/data/train/COCO_train2014_000000328120.jpg': ['a long line of parked bicycles in a large city',
#   'many bicycles parked on an asian city street',
#   'a lot about bicycles that our in the streets',
#   'many different bikes on a city street',
#   'a row of many bikes parked side by side'],
#  '/data/train/COCO_train2014_000000029104.jpg': ['a chef in a kitchen preparing a meal',
#   'a chef preparing food in a professional kitchen',
#   'a man puts a sauce on a food dish he is preparing',
#   'a chef pouring a sauce on food cooking on the stove',
#   'a young man is cooking ramen in a kitchen'],
#  '/data/train/COCO_train2014_000000577358.jpg': ['people walking by browse the windows of shops',
#   'some people stand on the street looking in a store window',
#   'a woman standing next to a bicycle and looking through a store window',
#   'people looking in the shop windows with a bicycle parked against the window',
#   'a woman is looking inside of a shop window'],
#  '/data/train/COCO_train2014_000000465595.jpg': ['three men are in a kitchen cooking and cutting through a dish',
#   'a man uses a knife to slice food for serving',
#   'three men in a kitchen preparing a dish',
#   'several men in the kitchen with one cutting a piece of meat',
#   'a man cutting up food sitting on top of a white plate'],
#  '/data/train/COCO_train2014_000000278860.jpg': ['a counter top with various kitchen items in a kitchen',
#   'the utensils have been neat arranged on the kitchen counter',
#   'kitchen counter scene showing wood cabinets knife set and a coffee maker',
#   'a kitchen filled with appliances and cooking utensils',
#   'a kitchen counter with appliances and knives on it'],
#  '/data/train/COCO_train2014_000000063573.jpg': ['a small tiled bathroom with white fixtures',
#   'the small bathroom has a shower made of glass',
#   'there is a small bathroom in beige and white colors and two toilets',
#   'a toilet and a bidet are in a beige tiled bathroom with a shower stall',
#   'an iamge of a bathroom with a toilet and a shower'],
#  '/data/train/COCO_train2014_000000087096.jpg': ['vendor in his stall selling various foods and bananas',
#   'a fruit stand with several bunches of hanging bananas',
#   'a lot of bananas and a person together',
#   'a person surrounded by bunches of bananas',
#   'a man standing inside of a store behind piles of ripe bananas'],
#  '/data/train/COCO_train2014_000000491128.jpg': ['a photograph of a bathroom inside a home',
#   'an open door shows a small bathroom space with a toilet and a shower while a sink sits near the open door',
#   'bathroom with its door open and is very clean',
#   'a welllit bathroom with the door open and shower',
#   'a well lit bathroom with a painted glass door'],
#  '/data/train/COCO_train2014_000000346699.jpg': ['a small tiled modern bathroom with walkin shower',
#   'a bathroom with a toilet sink and a shower',
#   'a very small and basic yet clean looking bathroom',
#   'a bathroom with sink toilet shower stall and beige tiles is shown',
#   'a bathroom as viewed from a door way'],
#  '/data/train/COCO_train2014_000000380350.jpg': ['three people tossing a frisbee on the beach',
#   'a girl throws a frisbee to two boys on a beach',
#   'a girl throws a frisbee on the beach',
#   'people that are playing on the bitch with frisbee',
#   'three young people catching frisbee on a sandy beach'],
#  '/data/train/COCO_train2014_000000056753.jpg': ['a kitchen with green walls and a cluttered counter',
#   'a kitchen is cluttered with bowels and cooking utensils',
#   'the kitchen counter of a partially renovated space',
#   'a kitchen scene with focus on the kitchen sink',
#   'dishes are placed on top of a kitchen counter'],
#  '/data/train/COCO_train2014_000000118794.jpg': ['two young men having a conversation in a kitchen area',
#   'two men in the kitchen of a log cabin at night',
#   'two people that are sitting in a kitchen talking',
#   'two men are in a cabin kitchen with one sitting on the counter',
#   'two men are talking in the kitchen of a cabin'],
#  '/data/train/COCO_train2014_000000343009.jpg': ['two women sit together peeling apples in a bowl',
#   'this appears to be a mother and daughter sharing a snack',
#   'two women are peeling a bowl of apples while seated',
#   'two women peel apples on chairs in a kitchen',
#   'two ladies sit on stools while peeling fruit in a bowl'],
#  '/data/train/COCO_train2014_000000471790.jpg': ['a very small kitchen in a mobile home',
#   'a sink and wood paneled oven in a vehicle',
#   'the door of a small oven is open',
#   'and evan that has the fence open to it',
#   'recreational vehicle kitchen with sink oven and dishwasher'],
#  '/data/train/COCO_train2014_000000087217.jpg': ['a kitchen with large tile floors and a big window',
#   'the kitchen is clean and white with plenty of light',
#   'a kitchen with a window that permits light',
#   'the small white kitchen has been cleaned spotlessy',
#   'an image of a kitchen setting with all white appliances'],
#  '/data/train/COCO_train2014_000000141200.jpg': ['a person that is walking in the rain',
#   'a lady all bundled up and holding an umbrella walks on',
#   'a woman walks in the rain with an umbrella',
#   'the woman is walking in the rain with an umbrella',
#   'a woman under an umbrella walking in the rain'],
#  '/data/train/COCO_train2014_000000207686.jpg': ['a white marbled bathroom with a rectangular window',
#   'a bathroom complete with a toilet sink and window',
#   'a bathroom is displayed with white marble walls',
#   'a white and chrome bathroom with a gray floor',
#   'this is a well designed bathroom that is plain and elegant at the same time'],
#  '/data/train/COCO_train2014_000000261298.jpg': ['a man relaxing on his love seat is doodling on his cell phone',
#   'a picture of a person sitting on the couch',
#   'a man is sittign on the couch with his cell phone',
#   'a man is relaxing in an overstuffed chair',
#   'a person sits in an easy chair using a cell phone background appears to possibly be a hair or nail salon'],
#  '/data/train/COCO_train2014_000000107249.jpg': ['the sink toilet and shower are close together in the small bathroom',
#   'a picture of a small tiled guest bathroom',
#   'a bathroom with white fixtures and tiled floor',
#   'a view inside of a bathroom with a shower',
#   'a tiled bathroom has a tub toilet and sink'],
#  '/data/train/COCO_train2014_000000110395.jpg': ['a brown dog standing in a shower looking miserable',
#   'a dog looks sad as it sits in the shower',
#   'a tan dog sitting in a shower getting a bath',
#   'large white wet dog wet sitting in the shower',
#   'a wet dog looks exhausted inside a shower stall'],
#  '/data/train/COCO_train2014_000000481391.jpg': ['a stove top with a tea kettle underneath a glass and wood set of cabinets',
#   'a kitchen with a red tea pot on the stove',
#   'a picture of a modern day kitchen with an orange tea kettle on the stove',
#   'a kitchen island with a teapot on the stove',
#   'kitchen with an island stove and clear cabinet spaces'],
#  '/data/train/COCO_train2014_000000521107.jpg': ['a bathroom with track lighting and a white toilet near a sink',
#   'a large tiled bathroom with a marble sink and white toilet',
#   'a clean and dimly lit modern hotel bathroom',
#   'an image of a bathroom with a toilet and a sink',
#   'a dimly lit clean bathroom featuring a toilet mirror and counter'],
#  '/data/train/COCO_train2014_000000506927.jpg': ['a man checking out a parked black scooter',
#   'a person standing near a small motorcycle on a city street',
#   'a man in a white shirt is looking at a three wheeled motorcycle',
#   'a man looks down at two low riding motor bikes',
#   'a guy staring at a weird looking bike'],
#  '/data/train/COCO_train2014_000000117178.jpg': ['a group of scooter enthusiasts parked at a red light',
#   'a group of people on motorized scooters on a city street',
#   'some people wearing helmets are riding mopeds and some buildings',
#   'a group of people ride together on their motorcycles',
#   'a group of kids riding on bikes on a road'],
#  '/data/train/COCO_train2014_000000071222.jpg': ['a large shower head in a bathroom shower',
#   'a tiled shower with a large shower head',
#   'the shower head has a blue light behind it',
#   'a shower head and a shower shelf with various toiletries',
#   'two shower heads in a shower along with a shelf of products'],
#  '/data/train/COCO_train2014_000000398105.jpg': ['a clean kitchen with overhead lights and tile flooring',
#   'a large kitchen sink next to an automatic dishwasher underneath track lighting',
#   'all of the cabinets in the kitchen are made of wood',
#   'a very clean kitchen with wooden shelves and a stainless steel dishwasher',
#   'a kitchen being lit by the outside sunlight'],
#  '/data/train/COCO_train2014_000000361638.jpg': ['a bathroom with a small white toilet sitting next to a walk in shower',
#   'a clean bathroom with sink mirror toilet and shower',
#   'a bathroom with a large mirror and walk in shower',
#   'a small cream tiled bathroom with a stand up shower',
#   'a white bathroom area with no shower curtain'],
#  '/data/train/COCO_train2014_000000322725.jpg': ['a man and a woman are looking at a camera',
#   'a man and a woman making goofy faces for a camera phone',
#   'a man taking a picture of himself and a woman on his cellphone camera',
#   'two people are laughing while looking at a picture on a cell phone',
#   'two adults making bizarre faces for a photo shot while drinking beer'],
#  '/data/train/COCO_train2014_000000385307.jpg': ['a kitchen with a center island covered in clutter',
#   'a kitchen with a number of old fasioned items and furnishings',
#   'an image of a kitchen setting with wine on the table',
#   'the old kitchen is made mostly of wooden paneling',
#   'there are some kitchen supplies on a kitchen table'],
#  '/data/train/COCO_train2014_000000073159.jpg': ['a man in a chefs coat kneels next to a rack of an oven',
#   'a blackandwhite photo of a man cooking in the kitchen',
#   'cook prepares dish by putting it into the oven',
#   'a man preparing food in a kitchen next to an oven',
#   'a man in a restaurant kitchen cooking in the oven'],
#  '/data/train/COCO_train2014_000000022857.jpg': ['a man preparing food in a professional kitchen',
#   'a chef preparing meals in an industrial kitchen',
#   'a man cooking in a commercial kitchen over an oven',
#   'a man is standinb by a grill in a kitchen with a stack of plates near him',
#   'a male chef working in a large kitchen with stainless steel fixtures'],
#  '/data/train/COCO_train2014_000000074335.jpg': ['a group of friends are standing laughing in the kitchen',
#   'several people stand in a kitchen area with brown cabinets',
#   'people are gathered in the kitchen one is holding a wine glass',
#   'friends laughing at a party while drinking beverages',
#   'several young people standing in the kitchen at a party'],
#  '/data/train/COCO_train2014_000000125821.jpg': ['a kitchen has dark brown cabinets and counter',
#   'a small kitchen with a refrigerator microwave and dishwasher',
#   'a kitchen with a microwave refrigerator and dishwasher',
#   'a picture of a very nice and clean kitchen',
#   'a corner of a small kitchen with cluttered counters'],
#  '/data/train/COCO_train2014_000000307759.jpg': ['a bike parked in a kitchen next to a dishwasher',
#   'an old kitchen with a bicycle parked in there',
#   'the curtain of the open kitchen window has been tied to one side',
#   'a kitchen that is in the middle of some repairs',
#   'a kitchen with various appliances and a bike on the floor'],
#  '/data/train/COCO_train2014_000000128647.jpg': ['several people that are talking to each other',
#   'there are people standing in the kitchen talking',
#   'three people in a kitchen with a counter top and a refrigerator',
#   'two men talking in the kitchen with a woman in the background',
#   'two men talk in a kitchen while a woman watches from the doorway'],
#  '/data/train/COCO_train2014_000000287039.jpg': ['a picture of a sink in a bathroom',
#   'a bathroom counter features a black counter and two square sinks',
#   'a clean bathroom with two sinks and a large mirror',
#   'a double sink counter with a black top in the bathroom',
#   'the bathroom vanity features double sinks in a unique rectangular shape'],
#  '/data/train/COCO_train2014_000000398053.jpg': ['a picture of a very clean kitchen in a house',
#   'the kitchen has a a white stove and refrigerator',
#   'a kitchen with white appliances and wood cabinets',
#   'kitchen with brown cabinets and white stove and refrigerator',
#   'a kitchen scene with an oven and a refrigerator'],
#  '/data/train/COCO_train2014_000000041455.jpg': ['a modern bathroom with two sinks and a television on the wall',
#   'a bathroom with two odd shaped sinks under a large mirror',
#   'a bathroom with double sinks and tiled bathtub',
#   'an image of bathroom setting with two faucets and a tv',
#   'a tiled bathroom with square sinks and large mirror'],
#  ...}

# %%
def add_end_start_tokens(image_captions_mapping):
    result = {}
    for key in image_captions_mapping:
        for i in range(len(image_captions_mapping[key])):
            result.setdefault(key, []).append(f'{START_TOKEN} {image_captions_mapping[key][i]} {END_TOKEN}')
    return result

# %%
b = add_end_start_tokens(a)
b
# Out:
# {'/data/train/COCO_train2014_000000318556.jpg': ['<start> a very clean and well decorated empty bathroom <end>',
#   '<start> a blue and white bathroom with butterfly themed wall tiles <end>',
#   '<start> a bathroom with a border of butterflies and blue paint on the walls above it <end>',
#   '<start> an angled view of a beautifully decorated bathroom <end>',
#   '<start> a clock that blends in with the wall hangs in a bathroom <end>'],
#  '/data/train/COCO_train2014_000000116100.jpg': ['<start> a panoramic view of a kitchen and all of its appliances <end>',
#   '<start> a panoramic photo of a kitchen and dining room <end>',
#   '<start> a wide angle view of the kitchen work area <end>',
#   '<start> multiple photos of a brown and white kitchen <end>',
#   '<start> a kitchen that has a checkered patterned floor and white cabinets <end>'],
#  '/data/train/COCO_train2014_000000379340.jpg': ['<start> a graffitied stop sign across the street from a red car <end>',
#   '<start> a vandalized stop sign and a red beetle on the road <end>',
#   '<start> a red stop sign with a bush bumper sticker under the word stop <end>',
#   '<start> a stop sign that has been vandalized is pictured in front of a parked car <end>',
#   '<start> a street sign modified to read stop bush <end>'],
#  '/data/train/COCO_train2014_000000134754.jpg': ['<start> the two people are walking down the beach <end>',
#   '<start> two people carrying surf boards on a beach <end>',
#   '<start> two teenagers at a white sanded beach with surfboards <end>',
#   '<start> a couple at the beach walking with their surf boards <end>',
#   '<start> a guy and a girl are walking on the beach holding surfboards <end>'],
#  '/data/train/COCO_train2014_000000538480.jpg': ['<start> a sink and a toilet inside a small bathroom <end>',
#   '<start> white pedestal sink and toilet located in a poorly lit bathroom <end>',
#   '<start> clean indoor bathroom with tiled floor and good lighting <end>',
#   '<start> a bathroom with toilet and sink and blue wall <end>',
#   '<start> a blue bathroom with a sink and toilet <end>'],
#  '/data/train/COCO_train2014_000000476220.jpg': ['<start> an empty kitchen with white and black appliances <end>',
#   '<start> a refrigerator and stove are in a small kitchen area <end>',
#   '<start> small kitchen in a personal home with dual sinks <end>',
#   '<start> a small kitchen with sink stove and refrigerator <end>',
#   '<start> a small kitchen with several appliances and cookware <end>'],
#  '/data/train/COCO_train2014_000000299675.jpg': ['<start> a white square kitchen with tile floor that needs repairs <end>',
#   '<start> a white kitchen in a home with the light on <end>',
#   '<start> a kitchen with a tile floor has cabinets with no doors a dishwasher a sink and a refrigerator <end>',
#   '<start> a white kitchen without doors on the cabinets <end>',
#   '<start> a white kitchen filled with pots pans and dishes <end>'],
#  '/data/train/COCO_train2014_000000032275.jpg': ['<start> the vanity contains two sinks with a towel for each <end>',
#   '<start> a clean restroom with towels and washcloths laid out <end>',
#   '<start> the bathroom counter is stocked with towels and supplies <end>',
#   '<start> there is a clean bathroom counter and sink <end>',
#   '<start> a hotel bathroom with stone counter and mirror <end>'],
#  '/data/train/COCO_train2014_000000302443.jpg': ['<start> several metal balls sit in the sand near a group of people <end>',
#   '<start> people standing around many silver round balls on the ground <end>',
#   '<start> silver balls are lined up in the sand as people mill about in the background <end>',
#   '<start> silver balls on sand with people walking around <end>',
#   '<start> silver balls laying on the ground around a smaller red ball <end>'],
#  '/data/train/COCO_train2014_000000025470.jpg': ['<start> a kitchen with brown cabinets tile backsplash and grey counters <end>',
#   '<start> a kitchen contains black countertops brown cabinets and a red and white tile blacksplash <end>',
#   '<start> a clean organized kitchen cabinet and countertop area <end>',
#   '<start> a kitchen has red bricks lining the counter <end>',
#   '<start> a kitchen with wood cabinets and granite counter tops <end>'],
#  '/data/train/COCO_train2014_000000513461.jpg': ['<start> a surfer a woman and a child walk on the beach <end>',
#   '<start> a person holding a surf board on a beach <end>',
#   '<start> a family standing next to the ocean on a sandy beach with a surf board <end>',
#   '<start> a man getting ready to surf as lookers walk by <end>',
#   '<start> a family carrying a surfboard to the ocean <end>'],
#  '/data/train/COCO_train2014_000000018691.jpg': ['<start> a few people sit on a dim transportation system <end>',
#   '<start> six people on a bus at night time <end>',
#   '<start> random people sitting in a public tranport bus <end>',
#   '<start> there are only a few people in the bus <end>',
#   '<start> a group of people are riding the bus <end>'],
#  '/data/train/COCO_train2014_000000285579.jpg': ['<start> a person protected from the rain by their umbrella walks down the road <end>',
#   '<start> a person walking outside in the rain with a green umbrella <end>',
#   '<start> a student walks in the rain with a green umbrella <end>',
#   '<start> an individual covers himself under an umbrella on a rainy day <end>',
#   '<start> a man walking in the rain crossing a street while holding an umbrella <end>'],
#  '/data/train/COCO_train2014_000000266366.jpg': ['<start> the bathroom with a toilet has an interesting sink <end>',
#   '<start> a demonstration of a well maintained hotel bathroom <end>',
#   '<start> a clean mediocre motel bathroom with a nice sink <end>',
#   '<start> a modern hotel bathroom with accessories set out <end>',
#   '<start> a bathroom with a toilet sink mirror and shower stall <end>'],
#  '/data/train/COCO_train2014_000000226658.jpg': ['<start> two women preparing food in a kitchen one at the sink and one at the table <end>',
#   '<start> a set table with silverware glasses and a bottle of wine <end>',
#   '<start> a woman having a slice of bread with jelly <end>',
#   '<start> a woman sitting at a table with win and bread <end>',
#   '<start> a women who is tearing off a piece of bread <end>'],
#  '/data/train/COCO_train2014_000000124567.jpg': ['<start> a cat stuck in a car with a slightly opened window <end>',
#   '<start> a cat peeking out a car window that is rolled down <end>',
#   '<start> a cat standing on a car seat looking out the car window <end>',
#   '<start> a person is taking a photo of a cat in a car <end>',
#   '<start> a cat sitting on top of the passenger seat of a car <end>'],
#  '/data/train/COCO_train2014_000000293605.jpg': ['<start> two bicycles and a woman walking in front of a shop <end>',
#   '<start> a woman walks by a couple of shop windows <end>',
#   '<start> woman walking down the street past a wig shop <end>',
#   '<start> a storefront with two bicycles and a woman walking past <end>',
#   '<start> a woman passing a store front wearing a long blue coat <end>'],
#  '/data/train/COCO_train2014_000000321194.jpg': ['<start> green tiled backsplash highlighted by low overhead lighting <end>',
#   '<start> a kitchen counter is illuminated by a hood light <end>',
#   '<start> a kitchen sink next to an empty counter with a tiled wall <end>',
#   '<start> a back splash is added to the wall in the kitchen <end>',
#   '<start> a picture of a sink top with dim lighting <end>'],
#  '/data/train/COCO_train2014_000000479495.jpg': ['<start> a bicycle is parked by a bench at night <end>',
#   '<start> a bike on the platform of a public transportation stop at night <end>',
#   '<start> a bicycle leans on a bench at a subway stop <end>',
#   '<start> a bicycle parked next to a bench in a train station <end>',
#   '<start> a bike and a bench on the side of a street <end>'],
#  '/data/train/COCO_train2014_000000539984.jpg': ['<start> a brown horse is grazing grass near a red house <end>',
#   '<start> a skinny horse is grazing in a field <end>',
#   '<start> a large hours is eating grass in a field <end>',
#   '<start> a brown horse is grazing in the grass <end>',
#   '<start> a brown horse grazes in an open field next to trees <end>'],
#  '/data/train/COCO_train2014_000000028231.jpg': ['<start> a black car is near someone riding a bike <end>',
#   '<start> a person on a bicycle is riding in front of a car <end>',
#   '<start> a blurry bike rider zooms past a new mercedes <end>',
#   '<start> a blurry bicycle riders goes by a black car <end>',
#   '<start> a man rides a bike past a black car in a parking lot <end>'],
#  '/data/train/COCO_train2014_000000350235.jpg': ['<start> this is a pickup game of shirts and skins basketball <end>',
#   '<start> a group of people playing a game of basketball <end>',
#   '<start> a group of men standing around while one seems angry at the others <end>',
#   '<start> several athletes appear to be having a disagreement <end>',
#   '<start> a man attempts to separate men during a fight at a street basketball game <end>'],
#  '/data/train/COCO_train2014_000000314265.jpg': ['<start> a toilet sink bathtub with shower mirror and cabinet <end>',
#   '<start> a small bathroom painted white with an empty shower <end>',
#   '<start> white bathroom with glass shelves and wood sink <end>',
#   '<start> a bathroom with an over the toilet cabinet <end>',
#   '<start> in the bathroom there is a shower sink and toilet <end>'],
#  '/data/train/COCO_train2014_000000389006.jpg': ['<start> a kitchen with a countertop that includes an apple phone <end>',
#   '<start> a phone and a computer on a kitchen counter <end>',
#   '<start> a phone lies on the counter in a modern kitchen <end>',
#   '<start> a nicely decorated kitchen with metallic refrigerator and blue counter <end>',
#   '<start> a clean kitchen with a phone and laptop on the counter <end>'],
#  '/data/train/COCO_train2014_000000031813.jpg': ['<start> a surfer riding his bike to the beach <end>',
#   '<start> a surfer rides his bike down the street <end>',
#   '<start> a man riding a bicycle on a road carrying a surf board <end>',
#   '<start> a man on a bike carrying a surfboard under his arm <end>',
#   '<start> a man rides a bike down the street while holding a surfboard <end>'],
#  '/data/train/COCO_train2014_000000465049.jpg': ['<start> a closeup of a red fire hydrant including the chains <end>',
#   '<start> a fire hydrant with chains is painted red <end>',
#   '<start> a red fire hydrant wrapped in a red chain on a sidewalk <end>',
#   '<start> the chain of a red fire hydrant is the focus <end>',
#   '<start> a fire hydrant and the chain attached to it <end>'],
#  '/data/train/COCO_train2014_000000360334.jpg': ['<start> a man standing in the kitchen with his arms crossed <end>',
#   '<start> young man with folded arms standing in the kitchen <end>',
#   '<start> a man standing in a white kitchen with his arms folded <end>',
#   '<start> a man folds his arms in a kitchen <end>',
#   '<start> man standing in a kitchen with his arms crossed <end>'],
#  '/data/train/COCO_train2014_000000524679.jpg': ['<start> a purple bus and a man dressed as a nun on a tall bicycle <end>',
#   '<start> sister on her bike trying to race the bus <end>',
#   '<start> a person riding a very high bike on the road <end>',
#   '<start> a nun riding a very tallk bike next to a purple bus <end>',
#   '<start> a woman in a nun costume is riding a bike next to a bus <end>'],
#  '/data/train/COCO_train2014_000000279672.jpg': ['<start> an herb that is in front of a toaster oven <end>',
#   '<start> a vegetable in front of a toaster oven <end>',
#   '<start> an evergreen sprig is sitting on top of an appliance <end>',
#   '<start> a microwave is next to sage or some kind of spice <end>',
#   '<start> this is a toaster with a green stem from a tree in front of it <end>'],
#  '/data/train/COCO_train2014_000000385716.jpg': ['<start> lady carrying a purse walking along side a man <end>',
#   '<start> a city sidewalk is lined with lamp posts <end>',
#   '<start> a man and a woman stand on the sidewalk lined with street lights <end>',
#   '<start> a city sidewalk with storefronts on the right <end>',
#   '<start> two people leaving a building to walk down the street <end>'],
#  '/data/train/COCO_train2014_000000044816.jpg': ['<start> clean bathroom that is brightly colored and has a window <end>',
#   '<start> a toilet sits next to a sink in a bathroom <end>',
#   '<start> a pristine bathroom sits waiting to be used <end>',
#   '<start> an empty bathroom painted yellow with an open window <end>',
#   '<start> this is a photo of a small hotel bathroom <end>'],
#  '/data/train/COCO_train2014_000000360306.jpg': ['<start> a man working at a kitchen counter in a room illuminated by sunlight <end>',
#   '<start> a man in shorts standing at the kitchen sink <end>',
#   '<start> a man is washing dishes in the kitchen sink <end>',
#   '<start> a man standing in a kitchen with a baby and dog <end>',
#   '<start> a man in a kitchen with his family in a house <end>'],
#  '/data/train/COCO_train2014_000000122802.jpg': ['<start> a man standing in a kitchen with granite countertops <end>',
#   '<start> an old man in the middle of his kitchen <end>',
#   '<start> a man stands in the middle of his granite countertopped kitchen <end>',
#   '<start> a man leaning forward on a counter top <end>',
#   '<start> a man stands behind a granite kitchen countertop with industrial lighting overhead <end>'],
#  '/data/train/COCO_train2014_000000515040.jpg': ['<start> seagulls flying overhead while trucks sit in a parking lot <end>',
#   '<start> a seagull perches on top of a van <end>',
#   '<start> a white van parked out side of a large white building <end>',
#   '<start> a white van sits outside of a white building <end>',
#   '<start> a white van parked with a seagull standing on top of it <end>',
#   '<start> single seagull sits on a white van with others flying in background <end>'],
#  '/data/train/COCO_train2014_000000161657.jpg': ['<start> a modern bathroom contains many glass and tile pieces <end>',
#   '<start> a bathroom with a white toilet and a white bath <end>',
#   '<start> the overhead view of a tiled bathroom with a tub shower toilet bidet and sink <end>',
#   '<start> a bathroom dimly lit with a bathtub and a shower <end>',
#   '<start> a bathroom with bathtub shower bidet toilet and sink <end>'],
#  '/data/train/COCO_train2014_000000072704.jpg': ['<start> a black cat making an angry face while sitting on the bathroom floor <end>',
#   '<start> a black cat sits next to laundry on the floor <end>',
#   '<start> a black cat sitting next to dirty clothes on the bathroom floor <end>',
#   '<start> a black cat sits on a bathroom floor next to some laundry <end>',
#   '<start> a cat sitting on a bath rug next to a pile of clothes <end>'],
#  '/data/train/COCO_train2014_000000028149.jpg': ['<start> a bathroom with a tv near the mirror <end>',
#   '<start> a television reflected off a mirror near a counter top <end>',
#   '<start> a flat screen tv sits next to a box of tissues and a remote control <end>',
#   '<start> a tv is behind glass in a bathroom <end>',
#   '<start> a hotel bathroom that has technology in the mirror <end>'],
#  '/data/train/COCO_train2014_000000257263.jpg': ['<start> a public restroom toilet has been photographed in sepia <end>',
#   '<start> a restroom with the toilet in the corner <end>',
#   '<start> a toilet is equipped with support bars for the disabled <end>',
#   '<start> a bathroom toilet is surrounded with silver handrails <end>',
#   '<start> toilet paper on the floor below a public toilet <end>'],
#  '/data/train/COCO_train2014_000000520049.jpg': ['<start> photo of a man riding an old styled bicycle near what appears to be the golden gate bridge <end>',
#   '<start> a man rides a bicycle across the river <end>',
#   '<start> man riding on a very old version of a personal bicycle <end>',
#   '<start> a man on an oldfashioned bicycle biking across a bridge <end>',
#   '<start> a man in a yellow coat rides an oldfashioned bicycle <end>'],
#  '/data/train/COCO_train2014_000000503598.jpg': ['<start> there is some pet food in the floor in an empty kitchen <end>',
#   '<start> a kitchen sink counter pots and a dog dish <end>',
#   '<start> there is a small kitchen with wooden cabinets and pet bowls on the floor <end>',
#   '<start> a kitchen with a pets food dishes on the floor <end>',
#   '<start> a very clean kitchen with some animal food on the ground <end>'],
#  '/data/train/COCO_train2014_000000230843.jpg': ['<start> a young boy surfing in low waves <end>',
#   '<start> a young boy is standing on a surfboard and riding a wave <end>',
#   '<start> a surfer rides his surf board on some very small waves <end>',
#   '<start> a young boy is standing on a surfboard in the water <end>',
#   '<start> a young boy is standing on a surfboard in the ocean <end>'],
#  '/data/train/COCO_train2014_000000231029.jpg': ['<start> the top of a kitchen cabinet covered with brass pots and pans <end>',
#   '<start> a kitchen with some old fashioned kitchen ware <end>',
#   '<start> a kitchen with copper pots on pot racks and on the stove <end>',
#   '<start> a restaurant kitchen with bowls and pans ready for the night <end>',
#   '<start> a kitchen with several brass pots and pans on stove tops <end>'],
#  '/data/train/COCO_train2014_000000174028.jpg': ['<start> a woman is shaving her face while sitting on a wooden bench <end>',
#   '<start> two girls sitting on a bench eating lunch <end>',
#   '<start> a girl demonstrating the act of shaving sitting on a bench <end>',
#   '<start> a girl trusts another girl to shave her while sitting back to back <end>',
#   '<start> two females sitting on a bench one is being the arms for the other <end>'],
#  '/data/train/COCO_train2014_000000480489.jpg': ['<start> the sky is full of colorful kites along a mountain <end>',
#   '<start> a large kite in the shape of the bottom half of a woman <end>',
#   '<start> the parachutes fly through the sky next to each other <end>',
#   '<start> assorted decorations laying around on a plastic tarp <end>',
#   '<start> a plethora of kites flying in the sky next to some mountains <end>'],
#  '/data/train/COCO_train2014_000000056972.jpg': ['<start> a bathroom in white has a cupboard above the sink <end>',
#   '<start> a bathroom sink and cabinet featuring everything white <end>',
#   '<start> a bathroom with a sink cabinet mirror and picture <end>',
#   '<start> a white pedestal sink below a white cabinet in a white bathroom <end>',
#   '<start> a modern bathroom sink and wall deco is shown <end>'],
#  '/data/train/COCO_train2014_000000187042.jpg': ['<start> a bike and a raft sit atop a boat on the water <end>',
#   '<start> a boat in the water with a raft and a bike loaded at one end of it <end>',
#   '<start> a boat has a raft and a bicycle on it <end>',
#   '<start> the front of a boat with a raft and bicycle on it <end>',
#   '<start> a small boat with a raft and bike strapped to it in a body of water <end>'],
#  '/data/train/COCO_train2014_000000101891.jpg': ['<start> bicycles cars and a trash can in a garage <end>',
#   '<start> clutter blocks antique cars from leaving the garage <end>',
#   '<start> a garage filled with old cards and old bicycles <end>',
#   '<start> some antique cars sit in a garage with some bicycles <end>',
#   '<start> a garage with bicycles cars and a garbage can <end>'],
#  '/data/train/COCO_train2014_000000090359.jpg': ['<start> a man jumping his bicycle onto a bench <end>',
#   '<start> a man balancing a bike on a bench <end>',
#   '<start> a man does a trick on a bike on a bench <end>',
#   '<start> a young man rides his bicycle on top of a cement bench <end>',
#   '<start> a man on a bicycle performing tricks on a bench <end>'],
#  '/data/train/COCO_train2014_000000213532.jpg': ['<start> black and white image of two children paying attention <end>',
#   '<start> a boy holding his arm around the shoulders of the girl sitting next to him <end>',
#   '<start> a boy places his arm around a friend <end>',
#   '<start> one kid has his arm wrapped around the other kid <end>',
#   '<start> two children sitting down one with his arm over the other <end>'],
#  '/data/train/COCO_train2014_000000024091.jpg': ['<start> a compact car with bicycles mounted on the roof <end>',
#   '<start> a car with a bunch of bicycles strapped to its roof <end>',
#   '<start> a car with several bikes on a bike rack <end>',
#   '<start> a car is loaded down with many bicycles attached to its roof <end>',
#   '<start> a car has multiple bikes hooked onto its roof <end>'],
#  '/data/train/COCO_train2014_000000372427.jpg': ['<start> a crisp neutral bathroom embellished with modern treatments <end>',
#   '<start> the toilet is next to a curtained window <end>',
#   '<start> curtains hanging in a bathroom window beside a toilet <end>',
#   '<start> a bathroom window reveals a snowy day outside <end>',
#   '<start> a tan bathroom with black curtains and towel <end>'],
#  '/data/train/COCO_train2014_000000376047.jpg': ['<start> a kitchen scene with stainless steel appliance and a checkered pattern floor <end>',
#   '<start> a kitchen with new age appliances and equipment <end>',
#   '<start> silver and white colored personal kitchen with yellow tiling <end>',
#   '<start> a modern lighted kitchen with stainless steel appliances <end>',
#   '<start> a picture of some appliances stove dishwasher refridgerator and microwave in a kitchen <end>'],
#  '/data/train/COCO_train2014_000000577876.jpg': ['<start> a lady talking a self portrait in a fancy bathroom <end>',
#   '<start> a woman takes a selfie in front of a restroom mirror <end>',
#   '<start> a woman takes a photo of her reflection in a bathroom mirror <end>',
#   '<start> a woman takes her picture in the mirror in the bathroom <end>',
#   '<start> a woman taking a self shot at an ornate mirror and sink <end>'],
#  '/data/train/COCO_train2014_000000047093.jpg': ['<start> a woman walking and talking on a cell phone <end>',
#   '<start> a female student is talking on her phone while walking <end>',
#   '<start> a young woman walking down the street while talking on her cell phone <end>',
#   '<start> two young women walking while one is on a cell phone <end>',
#   '<start> two young woman walking by a fire hydrant one talking on cell <end>'],
#  '/data/train/COCO_train2014_000000374873.jpg': ['<start> a man on top of a snowy mountain with skis <end>',
#   '<start> a group of skiers stand atop a snowy peak <end>',
#   '<start> group of skiers atop a mountain looking over edge <end>',
#   '<start> a man poses for a picture on top of a snowy hill <end>',
#   '<start> skiers are standing at the top of a snowcovered mountain <end>'],
#  '/data/train/COCO_train2014_000000360053.jpg': ['<start> a stuffed animal is laying on the bed by a window <end>',
#   '<start> a white bear laying on a bed with someones hand on the other side <end>',
#   '<start> a white teddy bear is laying on a bed in a dimly lit room <end>',
#   '<start> a teddy bear lying face down on a bedspread covered mattress in front of a window <end>',
#   '<start> a bed with blue bed spread on it in front of a window <end>'],
#  '/data/train/COCO_train2014_000000517565.jpg': ['<start> a wooden toilet seat sits open in an empty bathroom <end>',
#   '<start> a bathroom with a sink shower and toilette <end>',
#   '<start> a bathroom with a toilet and a sink <end>',
#   '<start> bathroom shot of an open toilet and sink <end>',
#   '<start> an empty bathroom with the toilet seat up <end>'],
#  '/data/train/COCO_train2014_000000543882.jpg': ['<start> a decorated table covered with plates of food and vegetables <end>',
#   '<start> a buffet of different types of food sitting on a buffet table <end>',
#   '<start> a buffet table at a restaurant covered with food <end>',
#   '<start> the two banquet tables held a variety of meats dips and pastries <end>',
#   '<start> a display of many prepared food dishes arranged decoratively on serving table <end>'],
#  '/data/train/COCO_train2014_000000038682.jpg': ['<start> a picture of a man riding a bicycle at night <end>',
#   '<start> a man with a backpack rides a bicycle <end>',
#   '<start> a man using his bicycle to go down a street <end>',
#   '<start> a person with a backpack on riding by on a bike <end>',
#   '<start> a man riding a bike down the street at night <end>'],
#  '/data/train/COCO_train2014_000000568117.jpg': ['<start> thee cats sleeping on a bed with a person <end>',
#   '<start> three cats sleeping with their owners on a bed <end>',
#   '<start> three cats are sleeping on a bed with a person <end>',
#   '<start> a person is sleeping on the same bed as three cats <end>',
#   '<start> two black cats nap as a white cat lays on a sleeping persons chest <end>'],
#  '/data/train/COCO_train2014_000000186620.jpg': ['<start> a young man playing a game of frisbee <end>',
#   '<start> a man extends his hand out to catch a frisbee <end>',
#   '<start> a man in a courtyard reaches out to catch a frisbee <end>',
#   '<start> college student playing frisbee on a campus lawn <end>',
#   '<start> a man has a frisbee in mid air just out of his hand <end>'],
#  '/data/train/COCO_train2014_000000004377.jpg': ['<start> a group of people playing a game of croquet <end>',
#   '<start> a game of croquet is being played in a back yard <end>',
#   '<start> two guys and a girl playing croquet in the yard <end>',
#   '<start> a group of four people playing croquet on a lawn <end>',
#   '<start> a group of friends enjoy a game of croquet on a grassy fenced in field <end>'],
#  '/data/train/COCO_train2014_000000189278.jpg': ['<start> a chef opens up an oven in a kitchen <end>',
#   '<start> this is a restaurant kitchen with two industrial ovens <end>',
#   '<start> there are two ovens in a kitchen restaurant and one of them is being used <end>',
#   '<start> two ovens in use in a professional kitchen <end>',
#   '<start> a person standing in a kitchen next to an oven <end>'],
#  '/data/train/COCO_train2014_000000170045.jpg': ['<start> a woman standing beside a clean kitchen island <end>',
#   '<start> a woman standing behind the island in the kitchen <end>',
#   '<start> a woman making something in a kitchen <end>',
#   '<start> a woman stands in the kitchen surrounded by wood cabinets and stainless steel appliances <end>',
#   '<start> a woman is standing at the island counter in a kitchen <end>'],
#  '/data/train/COCO_train2014_000000416172.jpg': ['<start> a kitchen being prepared to get newly painted <end>',
#   '<start> the corner of an empty kitchen with cleaning products all over the counter <end>',
#   '<start> dirty kitchen with cleaning supplies placed allover the counters <end>',
#   '<start> an a kitchen is being cleaned and decluttered <end>',
#   '<start> a dirty kitchen that looks to be under construction <end>'],
#  '/data/train/COCO_train2014_000000309517.jpg': ['<start> a person standing in front of a large body of water as the sun sets <end>',
#   '<start> the silhouette of a person standing in front of a sunset over water <end>',
#   '<start> a person is standing in front of the ocean at sunset <end>',
#   '<start> a dark profile of a person set before a sunset on the beach <end>',
#   '<start> man standing like a shadow in front of the ocean <end>'],
#  '/data/train/COCO_train2014_000000274682.jpg': ['<start> an empty bathroom with a large mirror and sink <end>',
#   '<start> a bathroom with two sinks and a closet <end>',
#   '<start> a white bathroom with a walk in closet is shown <end>',
#   '<start> a bathroom under construction with a double sink vanity that has a mirrir and light strip over it <end>',
#   '<start> a master bedroom with a closet and attached bathroom <end>'],
#  '/data/train/COCO_train2014_000000480545.jpg': ['<start> a set of stairs lead to a toilet and cabinet in a bathroom <end>',
#   '<start> the bathroom door next to the laundry room is open <end>',
#   '<start> through the door view of a small white bathroom <end>',
#   '<start> a small bathroom containing a step toilette and sink <end>',
#   '<start> the bathroom has a toilet sink tile floor and wooden panels on the outside <end>'],
#  '/data/train/COCO_train2014_000000210082.jpg': ['<start> double doors open into a bathroom with a footed tub <end>',
#   '<start> a freestanding bathroom near an open door and table <end>',
#   '<start> a bathroom scene with open double doors double sinks and a bathtub <end>',
#   '<start> a bathroom with the door open and a tub <end>',
#   '<start> there is an asian inspired bathroom with double doors <end>'],
#  '/data/train/COCO_train2014_000000474031.jpg': ['<start> an empty kitchen has walls painted white <end>',
#   '<start> a kitchen area with a microwave and refrigerator <end>',
#   '<start> a house with a white decorated kitchen <end>',
#   '<start> a large kitchen featuring a counter top and refrigerator <end>',
#   '<start> a large kitchen decorated with white flowers and books <end>'],
#  '/data/train/COCO_train2014_000000429065.jpg': ['<start> a colorful tent is stationed on a bike lane <end>',
#   '<start> a biker rides through a tent in a bike lane <end>',
#   '<start> a multicolored kiosk for cyclists in a city <end>',
#   '<start> colorful tent on a street is a stop for bicyclists <end>',
#   '<start> a shelter area for people on bicycles to warm up from the cold <end>'],
#  '/data/train/COCO_train2014_000000002448.jpg': ['<start> two kitchen stools sitting in front of an island in a kitchen <end>',
#   '<start> a kitchen counter with chairs refrigerator and cupboards <end>',
#   '<start> a picture of a kitchen area with refrigerator and stove <end>',
#   '<start> a kitchen with a refrigerator oven and counter <end>',
#   '<start> a very clean kitchen with the light on <end>'],
#  '/data/train/COCO_train2014_000000161749.jpg': ['<start> two dogs stand in a kitchen beneath their owner <end>',
#   '<start> two stands standing on the floor by their owners legs <end>',
#   '<start> two dogs with a woman in the kitchen <end>',
#   '<start> a photo on a kitchen floor with a persons legs and two dogs <end>',
#   '<start> person standing in the kitchen with two dogs at their feet <end>'],
#  '/data/train/COCO_train2014_000000435091.jpg': ['<start> a woman smiles at a man who is wearing a colorful sarong <end>',
#   '<start> man and woman with group of scissors on table <end>',
#   '<start> a shirtless man wearing a pink towel in the kitchen with a woman drinking wine <end>',
#   '<start> man dressed in a wrap in a personal kitchen <end>',
#   '<start> a man in a pink sarong showing scissors to a woman with wine <end>'],
#  '/data/train/COCO_train2014_000000385626.jpg': ['<start> woman riding a bicycle down an empty street <end>',
#   '<start> a woman in green is riding a bike <end>',
#   '<start> a woman wearing a bright green sweater riding a bicycle <end>',
#   '<start> a woman on a bicycle is going down the small town street <end>',
#   '<start> a woman bikes down a one way street <end>'],
#  '/data/train/COCO_train2014_000000180141.jpg': ['<start> a family sits at a table together enjoying each others company <end>',
#   '<start> a family is playing a karaoke video game <end>',
#   '<start> a family watches while two boys play a singing game <end>',
#   '<start> a family watches two boys singing into microphones <end>',
#   '<start> kids and their moms are singing karaoke at the table <end>'],
#  '/data/train/COCO_train2014_000000330238.jpg': ['<start> a crowd of skiers prepare to ski down snow covered slopes <end>',
#   '<start> many skiiers are gathered at the base of a hill while several travel down it <end>',
#   '<start> hikers climb up a snowcovered mountain in the winter <end>',
#   '<start> skiers of all ages skiing down a slope and gathering at the bottom <end>',
#   '<start> a group of people are skiing on a mountain <end>'],
#  '/data/train/COCO_train2014_000000499237.jpg': ['<start> towels are neatly stacked on a shelf in the bathroom <end>',
#   '<start> a table with towels on top of it placed under a mirror <end>',
#   '<start> a bathroom vanity with towels folded under the sink <end>',
#   '<start> a pedestal sink with vanity sits below a mirror <end>',
#   '<start> towels stored under a bathroom sink with a glass countertop <end>'],
#  '/data/train/COCO_train2014_000000466800.jpg': ['<start> a view of a fancy spa like bathroom with a blue tiled tub <end>',
#   '<start> different types of tiles are on the walls floor and tub <end>',
#   '<start> large modern bathroom with jacuzzi in a house <end>',
#   '<start> a modern bathtub in a bathroom is displayed <end>',
#   '<start> a nice bathroom with a standalone shower and a shower curtain <end>'],
#  '/data/train/COCO_train2014_000000279939.jpg': ['<start> a bathroom contains a toilet sink and bathtub <end>',
#   '<start> the white bathroom has orange blue and gray accents <end>',
#   '<start> a small bathroom with a white toilette and bath tub <end>',
#   '<start> a bathroom with toilet and bowl for sink <end>',
#   '<start> a bathroom with a toilet sink and bathtub <end>'],
#  '/data/train/COCO_train2014_000000526165.jpg': ['<start> loving couple pose together behind a fruitadorned cake <end>',
#   '<start> an older woman preparing to blow out the candle on her birthday cake standing besides an older man <end>',
#   '<start> a married couple posing in front of a piece of birthday cake <end>',
#   '<start> a man and woman smiling in front of a cake <end>',
#   '<start> a man and woman celebrating a special occasion about to blow out a candle <end>'],
#  '/data/train/COCO_train2014_000000334790.jpg': ['<start> a young man jumping his skate board over a cement seating area <end>',
#   '<start> boy riding skateboard and doing trick in air <end>',
#   '<start> a man in a blue shirt and jeans doing a trick on a skateboard <end>',
#   '<start> a skateboarder is airborne as he does a trick <end>',
#   '<start> a young man performing a trick on a skateboard <end>'],
#  '/data/train/COCO_train2014_000000014750.jpg': ['<start> a bicycle with a basket is parked at the side of a building <end>',
#   '<start> a bicycle leaning against a building near a window <end>',
#   '<start> a bicycle parked against the side of a stone house <end>',
#   '<start> a bicycle leaning against an old white building <end>',
#   '<start> a bicycle is parked up against a white stucco building <end>'],
#  '/data/train/COCO_train2014_000000573518.jpg': ['<start> a black colored keyboard for a computer system <end>',
#   '<start> a black computer keyboard with lcd panel and numeric pad <end>',
#   '<start> a wireless keyboard compatible with role playing games <end>',
#   '<start> a computer keyboard with black keys and white lettering <end>',
#   '<start> a black computer keyboard with a bunch of keys on it <end>'],
#  '/data/train/COCO_train2014_000000253464.jpg': ['<start> a mid sized bathroom with toilette shower and vanity mirror above a sink <end>',
#   '<start> a very clean bathroom with the lights on <end>',
#   '<start> the yellow flowers sits atop the counter in a clean bathroom <end>',
#   '<start> a very clean bathroom is shown with wood cabinets <end>',
#   '<start> a bathroom has a green and white striped shower curtain <end>'],
#  '/data/train/COCO_train2014_000000291827.jpg': ['<start> two boys with surf boards walking out into the ocean <end>',
#   '<start> surfers waiting for the right wave to ride <end>',
#   '<start> guys on their way to surfboard at the beach <end>',
#   '<start> people with surf boards going into the ocean <end>',
#   '<start> a group of surfers wade into the sea <end>'],
#  '/data/train/COCO_train2014_000000478007.jpg': ['<start> a bathroom sink and counter with a large mirror above it <end>',
#   '<start> a wood bathroom vanity with a granite countertop <end>',
#   '<start> this is a bathroom sink in a hotel <end>',
#   '<start> an indoor bathroom with reflective marble counter tops <end>',
#   '<start> a hotel room bathroom sink and tissue dispenser <end>'],
#  '/data/train/COCO_train2014_000000461221.jpg': ['<start> a kitchen with a over stove and toaster oven including a microwave <end>',
#   '<start> a kitchen with sink stove and a white cabinet <end>',
#   '<start> a kitchen cupboard in a kitchen with a stove and a sink <end>',
#   '<start> a large kitchen cabinet or pantry in a small kitchen <end>',
#   '<start> small clean kitchen with a large white cupboard <end>'],
#  '/data/train/COCO_train2014_000000416909.jpg': ['<start> an un occupied bathroom with a shower toilette and sink <end>',
#   '<start> a clean bathroom with sink toilet and shower <end>',
#   '<start> a small bathroom showing the sink and toilet area <end>',
#   '<start> a door leading to a bathroom with a sink visible <end>',
#   '<start> a door opening to a bathroom with orange shades and matching rug <end>'],
#  '/data/train/COCO_train2014_000000377955.jpg': ['<start> a silver car parked in a shopping center parking lot <end>',
#   '<start> a car is parked in a empty parking lot <end>',
#   '<start> the shopping plaza has many stores and one parked car <end>',
#   '<start> a silver sedan is parked in a plaza lot on a cloudy day <end>',
#   '<start> a small strip mall with a few cars in the parking lot <end>'],
#  '/data/train/COCO_train2014_000000550126.jpg': ['<start> a bathroom with a close shower curtain next to a toilette <end>',
#   '<start> a white shower curtain with a spiral pattern hanging in the bathroom <end>',
#   '<start> a bathroom with a toilet bowl and shower curtain <end>',
#   '<start> a bathroom has a large shower curtain with design <end>',
#   '<start> a closed shower curtain in a tiled bathroom <end>'],
#  '/data/train/COCO_train2014_000000194698.jpg': ['<start> a small dog cradled in his loving owners arm as he falls asleep <end>',
#   '<start> a person holding a chihuahua sleeping on its back in their arm <end>',
#   '<start> a person holding a small sleeping dog in their arms <end>',
#   '<start> a little dog is laying on a mans arm <end>',
#   '<start> a small dog taking a nap on the arm of a person <end>'],
#  '/data/train/COCO_train2014_000000579846.jpg': ['<start> a nearly empty house with a bicycle mounted on the wall <end>',
#   '<start> a hall opening onto a bathroom bedroom and two other rooms <end>',
#   '<start> a view of a hallway in a house <end>',
#   '<start> there is a hallway leading to a door where bicycle tires are showing <end>',
#   '<start> a house hallway with all the bedroom doors open <end>'],
#  '/data/train/COCO_train2014_000000009469.jpg': ['<start> a teenage boy is in a field looking at a wire <end>',
#   '<start> the boy is inspecting the wire for a project <end>',
#   '<start> a young guy checking on a wire as he holds onto a dog leash <end>',
#   '<start> a boy is outside with his dog in a field surrounded by a sign and other items <end>',
#   '<start> a boy building something with wires and poles <end>'],
#  '/data/train/COCO_train2014_000000348595.jpg': ['<start> a man in a parade has red and white face and umbrella <end>',
#   '<start> a young person with red and white face paint holds an umbrella <end>',
#   '<start> soccer fan is showing his support by dressing up <end>',
#   '<start> a man with a painted red and white face is standing in the street <end>',
#   '<start> a person with their face painted standing in the street <end>'],
#  '/data/train/COCO_train2014_000000079143.jpg': ['<start> a small bathroom has separate tub and shower <end>',
#   '<start> a spacious bathroom with a fancy bathtub and sink <end>',
#   '<start> a bathroom is lit by a light over a sink <end>',
#   '<start> a light is on in an empty clean bathroom <end>',
#   '<start> a shiny bathroom has an old fashioned bathtub and gold walls <end>'],
#  '/data/train/COCO_train2014_000000346909.jpg': ['<start> two dogs are laying down next to each other <end>',
#   '<start> two dogs were captured in a photo with the lighting of the image altered <end>',
#   '<start> two dogs sitting one the ground looking at something <end>',
#   '<start> two dogs are resting together on the floor <end>',
#   '<start> two doge have their paws out in an overexposed picture <end>'],
#  '/data/train/COCO_train2014_000000351191.jpg': ['<start> a woman crossing a city street while carrying groceries <end>',
#   '<start> shopper crossing a street in the downtown of a city <end>',
#   '<start> a person crossing at a crosswalk with bags in his hands <end>',
#   '<start> a city street scene with cars and a person crossing the street <end>',
#   '<start> a man is crossing a city intersection carrying bags <end>'],
#  '/data/train/COCO_train2014_000000165350.jpg': ['<start> a group of bike riders race down a busy street <end>',
#   '<start> a group of bikers round a turn on a road <end>',
#   '<start> cyclists competing in a race round a corner <end>',
#   '<start> a peleton of cyclists leaning into a turn <end>',
#   '<start> multiple cyclists riding their bikes on the street <end>'],
#  '/data/train/COCO_train2014_000000549575.jpg': ['<start> a kitchen filled with many cupboards and lots of counter space <end>',
#   '<start> an empty and very clean white and tan kitchen <end>',
#   '<start> unused kitchen stove sink and counter topsand cabinettes <end>',
#   '<start> a clean kitchen that is empty and white <end>',
#   '<start> an unfurnished kitchen in a tropical house hold <end>'],
#  '/data/train/COCO_train2014_000000387408.jpg': ['<start> an attractive woman taking a selfie in a bathroom <end>',
#   '<start> a selfie of a young woman in her bathroom <end>',
#   '<start> a woman is taking a picture of herself in the bathroom <end>',
#   '<start> a woman taking a selfie in a bathroom <end>',
#   '<start> a woman taking a photo of herself in the mirror <end>'],
#  '/data/train/COCO_train2014_000000331863.jpg': ['<start> a group of people sitting on a couch while a brown dog looks at them <end>',
#   '<start> a group of friends spending the day watching tv together <end>',
#   '<start> four friends lounge on a couch with a dog <end>',
#   '<start> a dog sits staring at a group of people <end>',
#   '<start> a group of people who are sitting together on a couch <end>'],
#  '/data/train/COCO_train2014_000000350553.jpg': ['<start> an older woman walking a bicycle with a bus in the background <end>',
#   '<start> a woman walks her bike past a city bus <end>',
#   '<start> a lady waking a bike by a bus <end>',
#   '<start> a woman walks her bicycle near a bus <end>',
#   '<start> a woman walking a bike while a bus passes by <end>'],
#  '/data/train/COCO_train2014_000000064941.jpg': ['<start> three people riding bikes on the side of a road <end>',
#   '<start> a group of two adults and a child biking down a road <end>',
#   '<start> two adults and a child riding bicycles on the side of a road <end>',
#   '<start> a couple and their child riding bikes down an asphalt road <end>',
#   '<start> a young family is biking in the bike lane of a road <end>'],
#  '/data/train/COCO_train2014_000000219409.jpg': ['<start> a fridge that is halfway open during the night <end>',
#   '<start> an open refrigerator in a kitchen next to a cupboard <end>',
#   '<start> a fridge door is open in a kitchen at night <end>',
#   '<start> an open refrigerator with a shinning bright light <end>',
#   '<start> lower door of refrigerator open in dark kitchen <end>'],
#  '/data/train/COCO_train2014_000000471895.jpg': ['<start> a bathroom featuring an oddly shaped toilette shower and sink <end>',
#   '<start> a small bathroom decorated with pretty red flowers <end>',
#   '<start> a bathroom with a toilet sink and a mirror <end>',
#   '<start> the bathroom has a shower area toilet and sink <end>',
#   '<start> a bathroom that has some flowers on the sink and toilet <end>'],
#  '/data/train/COCO_train2014_000000425135.jpg': ['<start> the inside of a bathroom with two sinks <end>',
#   '<start> a large bathroom with two sinks and three windows <end>',
#   '<start> a view of a communal bathroom with multiple sinks and windows <end>',
#   '<start> a bathroom with two porcelain sinks and hexagonal tiles <end>',
#   '<start> a bathroom with two sinks a bathtub and a shower with lots of lighting from the windows <end>'],
#  '/data/train/COCO_train2014_000000175565.jpg': ['<start> a cocker spaniel sitting next to a woman holding a baby <end>',
#   '<start> a dog lays on a couch next to a woman holding a baby <end>',
#   '<start> a dog is laying next to a woman holding a baby <end>',
#   '<start> a person sitting in a chair holding a baby and a dog <end>',
#   '<start> a woman holding a baby and sitting next to a dog <end>'],
#  '/data/train/COCO_train2014_000000178771.jpg': ['<start> a man on his skateboard at a basketball court <end>',
#   '<start> a young boy riding a skate board at a public skate park <end>',
#   '<start> a person skateboarding on an outside basketball court <end>',
#   '<start> a boy is doing tricks on his skateboard <end>',
#   '<start> a skateboarder has one end of the board in the air on top of a bench <end>'],
#  '/data/train/COCO_train2014_000000432201.jpg': ['<start> clean stainless steel kitchen with large cabinets and counter <end>',
#   '<start> a small spotless and clean stainless steel kitchen <end>',
#   '<start> a stainless steele kitchen with sinks and lots of storage <end>',
#   '<start> a restaurant kitchen stocked with stainless steel appliances <end>',
#   '<start> a kitchen with a sink ovens and dishes in it <end>'],
#  '/data/train/COCO_train2014_000000051644.jpg': ['<start> a srfer perches on his board precariously as he hits a big wave <end>',
#   '<start> a man riding a wave with a surfboard <end>',
#   '<start> a surfer catches a wave but is about to fall off his board <end>',
#   '<start> a man is surfing on some small ocean waves <end>',
#   '<start> a man on a surf board rides on some waves <end>'],
#  '/data/train/COCO_train2014_000000565401.jpg': ['<start> a bicycle leans against a park bench with a flowering tree nearby <end>',
#   '<start> a bicycle parked in the grass by a tree <end>',
#   '<start> a bicycle leaning up against a park bench <end>',
#   '<start> a bicycle leans on a bench in a park <end>',
#   '<start> the bicycle is parked beside of the bench outside <end>'],
#  '/data/train/COCO_train2014_000000256950.jpg': ['<start> the serving counter of a restaurant is quiet <end>',
#   '<start> a kitchen filled with dishes and bowls stacked on top of each other <end>',
#   '<start> kitchen ware sitting behind the counter top at a restaurant <end>',
#   '<start> the restaurant kitchen is highly lit displaying the colorful bowls <end>',
#   '<start> there are various utensils on the counter of a large kitchen <end>'],
#  '/data/train/COCO_train2014_000000276961.jpg': ['<start> a bathroom mirror with items in front of it <end>',
#   '<start> a mirror reflecting the opposite wall of a bathroom <end>',
#   '<start> a view of a mirror in a bathroom <end>',
#   '<start> a tiled bathroom vanity with a small mirror <end>',
#   '<start> a tiled bathroom with toothbrushes and shaving accessories <end>'],
#  '/data/train/COCO_train2014_000000530832.jpg': ['<start> two women prepare a meal in a large kitchen <end>',
#   '<start> two woman standing in a kitchen preparing food <end>',
#   '<start> two women working in a large kitchen with natural lighting <end>',
#   '<start> a wide angle view of a kitchen with two women working <end>',
#   '<start> two women in the kitchen standing by the sink <end>'],
#  '/data/train/COCO_train2014_000000211265.jpg': ['<start> an empty bathroom featuring a toilette and window <end>',
#   '<start> a bathroom toilet next to a window with a handicap bar next to it and a cabinet over it <end>',
#   '<start> a white bathroom with a tan toilet and a hand rail <end>',
#   '<start> a toilet bowl with a handicap rail next to it <end>',
#   '<start> the sunlight is shining brightly in the bathroom <end>'],
#  '/data/train/COCO_train2014_000000226517.jpg': ['<start> a kitchen with a wooden kitchen table and appliances in it <end>',
#   '<start> a kitchen has a wooden table and capinets <end>',
#   '<start> a kitchen scene with a dining room table and chairs <end>',
#   '<start> a kitchen with wooden drawers table chairs and stone counter tops <end>',
#   '<start> a kitchen with a table and chairs and various kitchen appliances <end>'],
#  '/data/train/COCO_train2014_000000209040.jpg': ['<start> a bathroom sink with mirror placed above it <end>',
#   '<start> a nice bathroom has a clean counter with makeup toothbrushes <end>',
#   '<start> a bathroom scene looking at the sink and mirror <end>',
#   '<start> a white background with white counter top and white walls <end>',
#   '<start> a bathroom with a sink and a mirror <end>'],
# ...
#   '<start> small child with blue toothbrush brushing his teeth <end>'],
#  '/data/train/COCO_train2014_000000558697.jpg': ['<start> several people stand next to a parked airplane where people are exiting the plane <end>',
#   '<start> a group of people disembarking from a plane at and airport <end>',
#   '<start> a plane that is on the ground in the nighttime <end>',
#   '<start> a dragonair plane awaiting boarding passengers at night <end>',
#   '<start> a huge chinese aircraft is sitting at an airport with people unloading <end>'],
#  '/data/train/COCO_train2014_000000328120.jpg': ['<start> a long line of parked bicycles in a large city <end>',
#   '<start> many bicycles parked on an asian city street <end>',
#   '<start> a lot about bicycles that our in the streets <end>',
#   '<start> many different bikes on a city street <end>',
#   '<start> a row of many bikes parked side by side <end>'],
#  '/data/train/COCO_train2014_000000029104.jpg': ['<start> a chef in a kitchen preparing a meal <end>',
#   '<start> a chef preparing food in a professional kitchen <end>',
#   '<start> a man puts a sauce on a food dish he is preparing <end>',
#   '<start> a chef pouring a sauce on food cooking on the stove <end>',
#   '<start> a young man is cooking ramen in a kitchen <end>'],
#  '/data/train/COCO_train2014_000000577358.jpg': ['<start> people walking by browse the windows of shops <end>',
#   '<start> some people stand on the street looking in a store window <end>',
#   '<start> a woman standing next to a bicycle and looking through a store window <end>',
#   '<start> people looking in the shop windows with a bicycle parked against the window <end>',
#   '<start> a woman is looking inside of a shop window <end>'],
#  '/data/train/COCO_train2014_000000465595.jpg': ['<start> three men are in a kitchen cooking and cutting through a dish <end>',
#   '<start> a man uses a knife to slice food for serving <end>',
#   '<start> three men in a kitchen preparing a dish <end>',
#   '<start> several men in the kitchen with one cutting a piece of meat <end>',
#   '<start> a man cutting up food sitting on top of a white plate <end>'],
#  '/data/train/COCO_train2014_000000278860.jpg': ['<start> a counter top with various kitchen items in a kitchen <end>',
#   '<start> the utensils have been neat arranged on the kitchen counter <end>',
#   '<start> kitchen counter scene showing wood cabinets knife set and a coffee maker <end>',
#   '<start> a kitchen filled with appliances and cooking utensils <end>',
#   '<start> a kitchen counter with appliances and knives on it <end>'],
#  '/data/train/COCO_train2014_000000063573.jpg': ['<start> a small tiled bathroom with white fixtures <end>',
#   '<start> the small bathroom has a shower made of glass <end>',
#   '<start> there is a small bathroom in beige and white colors and two toilets <end>',
#   '<start> a toilet and a bidet are in a beige tiled bathroom with a shower stall <end>',
#   '<start> an iamge of a bathroom with a toilet and a shower <end>'],
#  '/data/train/COCO_train2014_000000087096.jpg': ['<start> vendor in his stall selling various foods and bananas <end>',
#   '<start> a fruit stand with several bunches of hanging bananas <end>',
#   '<start> a lot of bananas and a person together <end>',
#   '<start> a person surrounded by bunches of bananas <end>',
#   '<start> a man standing inside of a store behind piles of ripe bananas <end>'],
#  '/data/train/COCO_train2014_000000491128.jpg': ['<start> a photograph of a bathroom inside a home <end>',
#   '<start> an open door shows a small bathroom space with a toilet and a shower while a sink sits near the open door <end>',
#   '<start> bathroom with its door open and is very clean <end>',
#   '<start> a welllit bathroom with the door open and shower <end>',
#   '<start> a well lit bathroom with a painted glass door <end>'],
#  '/data/train/COCO_train2014_000000346699.jpg': ['<start> a small tiled modern bathroom with walkin shower <end>',
#   '<start> a bathroom with a toilet sink and a shower <end>',
#   '<start> a very small and basic yet clean looking bathroom <end>',
#   '<start> a bathroom with sink toilet shower stall and beige tiles is shown <end>',
#   '<start> a bathroom as viewed from a door way <end>'],
#  '/data/train/COCO_train2014_000000380350.jpg': ['<start> three people tossing a frisbee on the beach <end>',
#   '<start> a girl throws a frisbee to two boys on a beach <end>',
#   '<start> a girl throws a frisbee on the beach <end>',
#   '<start> people that are playing on the bitch with frisbee <end>',
#   '<start> three young people catching frisbee on a sandy beach <end>'],
#  '/data/train/COCO_train2014_000000056753.jpg': ['<start> a kitchen with green walls and a cluttered counter <end>',
#   '<start> a kitchen is cluttered with bowels and cooking utensils <end>',
#   '<start> the kitchen counter of a partially renovated space <end>',
#   '<start> a kitchen scene with focus on the kitchen sink <end>',
#   '<start> dishes are placed on top of a kitchen counter <end>'],
#  '/data/train/COCO_train2014_000000118794.jpg': ['<start> two young men having a conversation in a kitchen area <end>',
#   '<start> two men in the kitchen of a log cabin at night <end>',
#   '<start> two people that are sitting in a kitchen talking <end>',
#   '<start> two men are in a cabin kitchen with one sitting on the counter <end>',
#   '<start> two men are talking in the kitchen of a cabin <end>'],
#  '/data/train/COCO_train2014_000000343009.jpg': ['<start> two women sit together peeling apples in a bowl <end>',
#   '<start> this appears to be a mother and daughter sharing a snack <end>',
#   '<start> two women are peeling a bowl of apples while seated <end>',
#   '<start> two women peel apples on chairs in a kitchen <end>',
#   '<start> two ladies sit on stools while peeling fruit in a bowl <end>'],
#  '/data/train/COCO_train2014_000000471790.jpg': ['<start> a very small kitchen in a mobile home <end>',
#   '<start> a sink and wood paneled oven in a vehicle <end>',
#   '<start> the door of a small oven is open <end>',
#   '<start> and evan that has the fence open to it <end>',
#   '<start> recreational vehicle kitchen with sink oven and dishwasher <end>'],
#  '/data/train/COCO_train2014_000000087217.jpg': ['<start> a kitchen with large tile floors and a big window <end>',
#   '<start> the kitchen is clean and white with plenty of light <end>',
#   '<start> a kitchen with a window that permits light <end>',
#   '<start> the small white kitchen has been cleaned spotlessy <end>',
#   '<start> an image of a kitchen setting with all white appliances <end>'],
#  '/data/train/COCO_train2014_000000141200.jpg': ['<start> a person that is walking in the rain <end>',
#   '<start> a lady all bundled up and holding an umbrella walks on <end>',
#   '<start> a woman walks in the rain with an umbrella <end>',
#   '<start> the woman is walking in the rain with an umbrella <end>',
#   '<start> a woman under an umbrella walking in the rain <end>'],
#  '/data/train/COCO_train2014_000000207686.jpg': ['<start> a white marbled bathroom with a rectangular window <end>',
#   '<start> a bathroom complete with a toilet sink and window <end>',
#   '<start> a bathroom is displayed with white marble walls <end>',
#   '<start> a white and chrome bathroom with a gray floor <end>',
#   '<start> this is a well designed bathroom that is plain and elegant at the same time <end>'],
#  '/data/train/COCO_train2014_000000261298.jpg': ['<start> a man relaxing on his love seat is doodling on his cell phone <end>',
#   '<start> a picture of a person sitting on the couch <end>',
#   '<start> a man is sittign on the couch with his cell phone <end>',
#   '<start> a man is relaxing in an overstuffed chair <end>',
#   '<start> a person sits in an easy chair using a cell phone background appears to possibly be a hair or nail salon <end>'],
#  '/data/train/COCO_train2014_000000107249.jpg': ['<start> the sink toilet and shower are close together in the small bathroom <end>',
#   '<start> a picture of a small tiled guest bathroom <end>',
#   '<start> a bathroom with white fixtures and tiled floor <end>',
#   '<start> a view inside of a bathroom with a shower <end>',
#   '<start> a tiled bathroom has a tub toilet and sink <end>'],
#  '/data/train/COCO_train2014_000000110395.jpg': ['<start> a brown dog standing in a shower looking miserable <end>',
#   '<start> a dog looks sad as it sits in the shower <end>',
#   '<start> a tan dog sitting in a shower getting a bath <end>',
#   '<start> large white wet dog wet sitting in the shower <end>',
#   '<start> a wet dog looks exhausted inside a shower stall <end>'],
#  '/data/train/COCO_train2014_000000481391.jpg': ['<start> a stove top with a tea kettle underneath a glass and wood set of cabinets <end>',
#   '<start> a kitchen with a red tea pot on the stove <end>',
#   '<start> a picture of a modern day kitchen with an orange tea kettle on the stove <end>',
#   '<start> a kitchen island with a teapot on the stove <end>',
#   '<start> kitchen with an island stove and clear cabinet spaces <end>'],
#  '/data/train/COCO_train2014_000000521107.jpg': ['<start> a bathroom with track lighting and a white toilet near a sink <end>',
#   '<start> a large tiled bathroom with a marble sink and white toilet <end>',
#   '<start> a clean and dimly lit modern hotel bathroom <end>',
#   '<start> an image of a bathroom with a toilet and a sink <end>',
#   '<start> a dimly lit clean bathroom featuring a toilet mirror and counter <end>'],
#  '/data/train/COCO_train2014_000000506927.jpg': ['<start> a man checking out a parked black scooter <end>',
#   '<start> a person standing near a small motorcycle on a city street <end>',
#   '<start> a man in a white shirt is looking at a three wheeled motorcycle <end>',
#   '<start> a man looks down at two low riding motor bikes <end>',
#   '<start> a guy staring at a weird looking bike <end>'],
#  '/data/train/COCO_train2014_000000117178.jpg': ['<start> a group of scooter enthusiasts parked at a red light <end>',
#   '<start> a group of people on motorized scooters on a city street <end>',
#   '<start> some people wearing helmets are riding mopeds and some buildings <end>',
#   '<start> a group of people ride together on their motorcycles <end>',
#   '<start> a group of kids riding on bikes on a road <end>'],
#  '/data/train/COCO_train2014_000000071222.jpg': ['<start> a large shower head in a bathroom shower <end>',
#   '<start> a tiled shower with a large shower head <end>',
#   '<start> the shower head has a blue light behind it <end>',
#   '<start> a shower head and a shower shelf with various toiletries <end>',
#   '<start> two shower heads in a shower along with a shelf of products <end>'],
#  '/data/train/COCO_train2014_000000398105.jpg': ['<start> a clean kitchen with overhead lights and tile flooring <end>',
#   '<start> a large kitchen sink next to an automatic dishwasher underneath track lighting <end>',
#   '<start> all of the cabinets in the kitchen are made of wood <end>',
#   '<start> a very clean kitchen with wooden shelves and a stainless steel dishwasher <end>',
#   '<start> a kitchen being lit by the outside sunlight <end>'],
#  '/data/train/COCO_train2014_000000361638.jpg': ['<start> a bathroom with a small white toilet sitting next to a walk in shower <end>',
#   '<start> a clean bathroom with sink mirror toilet and shower <end>',
#   '<start> a bathroom with a large mirror and walk in shower <end>',
#   '<start> a small cream tiled bathroom with a stand up shower <end>',
#   '<start> a white bathroom area with no shower curtain <end>'],
#  '/data/train/COCO_train2014_000000322725.jpg': ['<start> a man and a woman are looking at a camera <end>',
#   '<start> a man and a woman making goofy faces for a camera phone <end>',
#   '<start> a man taking a picture of himself and a woman on his cellphone camera <end>',
#   '<start> two people are laughing while looking at a picture on a cell phone <end>',
#   '<start> two adults making bizarre faces for a photo shot while drinking beer <end>'],
#  '/data/train/COCO_train2014_000000385307.jpg': ['<start> a kitchen with a center island covered in clutter <end>',
#   '<start> a kitchen with a number of old fasioned items and furnishings <end>',
#   '<start> an image of a kitchen setting with wine on the table <end>',
#   '<start> the old kitchen is made mostly of wooden paneling <end>',
#   '<start> there are some kitchen supplies on a kitchen table <end>'],
#  '/data/train/COCO_train2014_000000073159.jpg': ['<start> a man in a chefs coat kneels next to a rack of an oven <end>',
#   '<start> a blackandwhite photo of a man cooking in the kitchen <end>',
#   '<start> cook prepares dish by putting it into the oven <end>',
#   '<start> a man preparing food in a kitchen next to an oven <end>',
#   '<start> a man in a restaurant kitchen cooking in the oven <end>'],
#  '/data/train/COCO_train2014_000000022857.jpg': ['<start> a man preparing food in a professional kitchen <end>',
#   '<start> a chef preparing meals in an industrial kitchen <end>',
#   '<start> a man cooking in a commercial kitchen over an oven <end>',
#   '<start> a man is standinb by a grill in a kitchen with a stack of plates near him <end>',
#   '<start> a male chef working in a large kitchen with stainless steel fixtures <end>'],
#  '/data/train/COCO_train2014_000000074335.jpg': ['<start> a group of friends are standing laughing in the kitchen <end>',
#   '<start> several people stand in a kitchen area with brown cabinets <end>',
#   '<start> people are gathered in the kitchen one is holding a wine glass <end>',
#   '<start> friends laughing at a party while drinking beverages <end>',
#   '<start> several young people standing in the kitchen at a party <end>'],
#  '/data/train/COCO_train2014_000000125821.jpg': ['<start> a kitchen has dark brown cabinets and counter <end>',
#   '<start> a small kitchen with a refrigerator microwave and dishwasher <end>',
#   '<start> a kitchen with a microwave refrigerator and dishwasher <end>',
#   '<start> a picture of a very nice and clean kitchen <end>',
#   '<start> a corner of a small kitchen with cluttered counters <end>'],
#  '/data/train/COCO_train2014_000000307759.jpg': ['<start> a bike parked in a kitchen next to a dishwasher <end>',
#   '<start> an old kitchen with a bicycle parked in there <end>',
#   '<start> the curtain of the open kitchen window has been tied to one side <end>',
#   '<start> a kitchen that is in the middle of some repairs <end>',
#   '<start> a kitchen with various appliances and a bike on the floor <end>'],
#  '/data/train/COCO_train2014_000000128647.jpg': ['<start> several people that are talking to each other <end>',
#   '<start> there are people standing in the kitchen talking <end>',
#   '<start> three people in a kitchen with a counter top and a refrigerator <end>',
#   '<start> two men talking in the kitchen with a woman in the background <end>',
#   '<start> two men talk in a kitchen while a woman watches from the doorway <end>'],
#  '/data/train/COCO_train2014_000000287039.jpg': ['<start> a picture of a sink in a bathroom <end>',
#   '<start> a bathroom counter features a black counter and two square sinks <end>',
#   '<start> a clean bathroom with two sinks and a large mirror <end>',
#   '<start> a double sink counter with a black top in the bathroom <end>',
#   '<start> the bathroom vanity features double sinks in a unique rectangular shape <end>'],
#  '/data/train/COCO_train2014_000000398053.jpg': ['<start> a picture of a very clean kitchen in a house <end>',
#   '<start> the kitchen has a a white stove and refrigerator <end>',
#   '<start> a kitchen with white appliances and wood cabinets <end>',
#   '<start> kitchen with brown cabinets and white stove and refrigerator <end>',
#   '<start> a kitchen scene with an oven and a refrigerator <end>'],
#  '/data/train/COCO_train2014_000000041455.jpg': ['<start> a modern bathroom with two sinks and a television on the wall <end>',
#   '<start> a bathroom with two odd shaped sinks under a large mirror <end>',
#   '<start> a bathroom with double sinks and tiled bathtub <end>',
#   '<start> an image of bathroom setting with two faucets and a tv <end>',
#   '<start> a tiled bathroom with square sinks and large mirror <end>'],
#  ...}

# %%
def create_vocab(mapping, word_count_threshold = 10):
    # Create list of captions
    all_captions = []
    for captions in mapping.values():
        all_captions.extend(captions)

    # Allow only words which appear at least 10 times
    word_counts = {}
    nsents = 0
    for sent in all_captions:
        nsents += 1
        for w in sent.split(' '):
            word_counts[w] = word_counts.get(w, 0) + 1

    vocab = [w for w in word_counts if word_counts[w] >= word_count_threshold]

    return vocab

# %%
vocab = create_vocab(b)
vocab
# Out:
# ['<start>',
#  'a',
#  'very',
#  'clean',
#  'and',
#  'well',
#  'decorated',
#  'empty',
#  'bathroom',
#  '<end>',
#  'blue',
#  'white',
#  'with',
#  'butterfly',
#  'themed',
#  'wall',
#  'tiles',
#  'border',
#  'of',
#  'butterflies',
#  'paint',
#  'on',
#  'the',
#  'walls',
#  'above',
#  'it',
#  'an',
#  'angled',
#  'view',
#  'beautifully',
#  'clock',
#  'that',
#  'in',
#  'hangs',
#  'panoramic',
#  'kitchen',
#  'all',
#  'its',
#  'appliances',
#  'photo',
#  'dining',
#  'room',
#  'wide',
#  'angle',
#  'work',
#  'area',
#  'multiple',
#  'photos',
#  'brown',
#  'has',
#  'checkered',
#  'patterned',
#  'floor',
#  'cabinets',
#  'graffitied',
#  'stop',
#  'sign',
#  'across',
#  'street',
#  'from',
#  'red',
#  'car',
#  'vandalized',
#  'road',
#  'bush',
#  'bumper',
#  'sticker',
#  'under',
#  'word',
#  'been',
#  'is',
#  'pictured',
#  'front',
#  'parked',
#  'modified',
#  'to',
#  'read',
#  'two',
#  'people',
#  'are',
#  'walking',
#  'down',
#  'beach',
#  'carrying',
#  'surf',
#  'boards',
#  'teenagers',
#  'at',
#  'surfboards',
#  'couple',
#  'their',
#  'guy',
#  'girl',
#  'holding',
#  'sink',
#  'toilet',
#  'inside',
#  'small',
#  'pedestal',
#  'located',
#  'poorly',
#  'lit',
#  'indoor',
#  'tiled',
#  'good',
#  'lighting',
#  'black',
#  'refrigerator',
#  'stove',
#  'personal',
#  'home',
#  'dual',
#  'sinks',
#  'several',
#  'cookware',
#  'square',
#  'tile',
#  'needs',
#  'repairs',
#  'light',
#  'no',
#  'doors',
#  'dishwasher',
#  'without',
#  'filled',
#  'pots',
#  'pans',
#  'dishes',
#  'vanity',
#  'contains',
#  'towel',
#  'for',
#  'each',
#  'restroom',
#  'towels',
#  'laid',
#  'out',
#  'counter',
#  'stocked',
#  'supplies',
#  'there',
#  'hotel',
#  'stone',
#  'mirror',
#  'metal',
#  'balls',
#  'sit',
#  'sand',
#  'near',
#  'group',
#  'standing',
#  'around',
#  'many',
#  'silver',
#  'round',
#  'ground',
#  'lined',
#  'up',
#  'as',
#  'mill',
#  'about',
#  'background',
#  'laying',
#  'smaller',
#  'ball',
#  'backsplash',
#  'grey',
#  'counters',
#  'countertops',
#  'organized',
#  'cabinet',
#  'countertop',
#  'bricks',
#  'lining',
#  'wood',
#  'granite',
#  'tops',
#  'surfer',
#  'woman',
#  'child',
#  'walk',
#  'person',
#  'board',
#  'family',
#  'next',
#  'ocean',
#  'sandy',
#  'man',
#  'getting',
#  'ready',
#  'by',
#  'surfboard',
#  'few',
#  'dim',
#  'transportation',
#  'system',
#  'six',
#  'bus',
#  'night',
#  'time',
#  'random',
#  'sitting',
#  'public',
#  'only',
#  'riding',
#  'protected',
#  'rain',
#  'umbrella',
#  'walks',
#  'outside',
#  'green',
#  'student',
#  'individual',
#  'covers',
#  'himself',
#  'rainy',
#  'day',
#  'crossing',
#  'while',
#  'interesting',
#  'demonstration',
#  'maintained',
#  'motel',
#  'nice',
#  'modern',
#  'accessories',
#  'set',
#  'shower',
#  'stall',
#  'women',
#  'preparing',
#  'food',
#  'one',
#  'table',
#  'silverware',
#  'glasses',
#  'bottle',
#  'wine',
#  'having',
#  'slice',
#  'bread',
#  'jelly',
#  'win',
#  'who',
#  'off',
#  'piece',
#  'cat',
#  'stuck',
#  'slightly',
#  'opened',
#  'window',
#  'peeking',
#  'rolled',
#  'seat',
#  'looking',
#  'taking',
#  'top',
#  'passenger',
#  'bicycles',
#  'shop',
#  'windows',
#  'past',
#  'wig',
#  'storefront',
#  'passing',
#  'store',
#  'wearing',
#  'long',
#  'coat',
#  'low',
#  'overhead',
#  'illuminated',
#  'hood',
#  'back',
#  'splash',
#  'added',
#  'picture',
#  'bicycle',
#  'bench',
#  'bike',
#  'platform',
#  'leans',
#  'subway',
#  'train',
#  'station',
#  'side',
#  'horse',
#  'grazing',
#  'grass',
#  'house',
#  'skinny',
#  'field',
#  'large',
#  'hours',
#  'eating',
#  'grazes',
#  'open',
#  'trees',
#  'someone',
#  'blurry',
#  'rider',
#  'zooms',
#  'new',
#  'mercedes',
#  'riders',
#  'goes',
#  'rides',
#  'parking',
#  'lot',
#  'this',
#  'pickup',
#  'game',
#  'shirts',
#  'basketball',
#  'playing',
#  'men',
#  'seems',
#  'angry',
#  'others',
#  'athletes',
#  'appear',
#  'be',
#  'attempts',
#  'separate',
#  'during',
#  'fight',
#  'bathtub',
#  'painted',
#  'glass',
#  'shelves',
#  'over',
#  'includes',
#  'apple',
#  'phone',
#  'computer',
#  'lies',
#  'nicely',
#  'metallic',
#  'laptop',
#  'his',
#  'arm',
#  'closeup',
#  'fire',
#  'hydrant',
#  'including',
#  'chains',
#  'wrapped',
#  'chain',
#  'sidewalk',
#  'focus',
#  'attached',
#  'arms',
#  'crossed',
#  'young',
#  'folded',
#  'purple',
#  'dressed',
#  'tall',
#  'sister',
#  'her',
#  'trying',
#  'race',
#  'high',
#  'costume',
#  'herb',
#  'toaster',
#  'oven',
#  'vegetable',
#  'evergreen',
#  'appliance',
#  'microwave',
#  'or',
#  'some',
#  'kind',
#  'spice',
#  'stem',
#  'tree',
#  'lady',
#  'purse',
#  'along',
#  'city',
#  'lamp',
#  'posts',
#  'stand',
#  'lights',
#  'storefronts',
#  'right',
#  'leaving',
#  'building',
#  'brightly',
#  'colored',
#  'sits',
#  'pristine',
#  'waiting',
#  'used',
#  'yellow',
#  'working',
#  'sunlight',
#  'shorts',
#  'washing',
#  'baby',
#  'dog',
#  'old',
#  'middle',
#  'stands',
#  'leaning',
#  'forward',
#  'behind',
#  'industrial',
#  'seagulls',
#  'flying',
#  'trucks',
#  'seagull',
#  'perches',
#  'van',
#  'single',
#  'pieces',
#  'bath',
#  'tub',
#  'bidet',
#  'dimly',
#  'making',
#  'face',
#  'laundry',
#  'dirty',
#  'clothes',
#  'rug',
#  'pile',
#  'tv',
#  'television',
#  'reflected',
#  'flat',
#  'screen',
#  'box',
#  'tissues',
#  'remote',
#  'control',
#  'technology',
#  'photographed',
#  'sepia',
#  'corner',
#  'equipped',
#  'support',
#  'bars',
#  'surrounded',
#  'paper',
#  'below',
#  'styled',
#  'what',
#  'appears',
#  'golden',
#  'gate',
#  'bridge',
#  'river',
#  'version',
#  'oldfashioned',
#  'biking',
#  'pet',
#  'dish',
#  'wooden',
#  'bowls',
#  'pets',
#  'animal',
#  'boy',
#  'surfing',
#  'waves',
#  'wave',
#  'water',
#  'covered',
#  'brass',
#  'fashioned',
#  'ware',
#  'copper',
#  'pot',
#  'racks',
#  'restaurant',
#  'shaving',
#  'girls',
#  'lunch',
#  'demonstrating',
#  'act',
#  'another',
#  'females',
#  'being',
#  'other',
#  'sky',
#  'full',
#  'colorful',
#  'kites',
#  'mountain',
#  'kite',
#  'shape',
#  'bottom',
#  'half',
#  'parachutes',
#  'fly',
#  'through',
#  'assorted',
#  'decorations',
#  'plastic',
#  'tarp',
#  'plethora',
#  'mountains',
#  'cupboard',
#  'featuring',
#  'everything',
#  'shown',
#  'raft',
#  'atop',
#  'boat',
#  'loaded',
#  'end',
#  'strapped',
#  'body',
#  'cars',
#  'trash',
#  'can',
#  'garage',
#  'clutter',
#  'blocks',
#  'antique',
#  'cards',
#  'garbage',
#  'jumping',
#  'onto',
#  'balancing',
#  'does',
#  'trick',
#  'cement',
#  'performing',
#  'tricks',
#  'image',
#  'children',
#  'paying',
#  'attention',
#  'shoulders',
#  'him',
#  'places',
#  'friend',
#  'kid',
#  'compact',
#  'mounted',
#  'roof',
#  'bunch',
#  'bikes',
#  'rack',
#  'hooked',
#  'crisp',
#  'neutral',
#  'curtained',
#  'curtains',
#  'hanging',
#  'beside',
#  'reveals',
#  'snowy',
#  'tan',
#  'scene',
#  'stainless',
#  'steel',
#  'pattern',
#  'age',
#  'equipment',
#  'tiling',
#  'lighted',
#  'refridgerator',
#  'talking',
#  'self',
#  'portrait',
#  'fancy',
#  'takes',
#  'selfie',
#  'reflection',
#  'shot',
#  'ornate',
#  'cell',
#  'female',
#  'skis',
#  'skiers',
#  'peak',
#  'edge',
#  'poses',
#  'hill',
#  'snowcovered',
#  'stuffed',
#  'bed',
#  'bear',
#  'someones',
#  'hand',
#  'teddy',
#  'lying',
#  'bedspread',
#  'mattress',
#  'spread',
#  'toilette',
#  'plates',
#  'vegetables',
#  'buffet',
#  'different',
#  'types',
#  'banquet',
#  'tables',
#  'held',
#  'variety',
#  'meats',
#  'dips',
#  'pastries',
#  'display',
#  'prepared',
#  'arranged',
#  'serving',
#  'backpack',
#  'using',
#  'go',
#  'thee',
#  'cats',
#  'sleeping',
#  'three',
#  'owners',
#  'same',
#  'nap',
#  'lays',
#  'persons',
#  'chest',
#  'frisbee',
#  'extends',
#  'catch',
#  'courtyard',
#  'reaches',
#  'college',
#  'campus',
#  'lawn',
#  'mid',
#  'air',
#  'just',
#  'played',
#  'yard',
#  'guys',
#  'four',
#  'friends',
#  'enjoy',
#  'grassy',
#  'fenced',
#  'chef',
#  'opens',
#  'ovens',
#  'them',
#  'use',
#  'professional',
#  'island',
#  'something',
#  'get',
#  'newly',
#  'cleaning',
#  'products',
#  'placed',
#  'cleaned',
#  'looks',
#  'construction',
#  'sun',
#  'sets',
#  'silhouette',
#  'sunset',
#  'dark',
#  'profile',
#  'before',
#  'like',
#  'shadow',
#  'closet',
#  'double',
#  'strip',
#  'master',
#  'bedroom',
#  'stairs',
#  'lead',
#  'door',
#  'containing',
#  'step',
#  'panels',
#  'into',
#  'footed',
#  'asian',
#  'inspired',
#  'flowers',
#  'books',
#  'tent',
#  'stationed',
#  'lane',
#  'biker',
#  'multicolored',
#  'kiosk',
#  'cyclists',
#  'bicyclists',
#  'shelter',
#  'warm',
#  'cold',
#  'stools',
#  'chairs',
#  'cupboards',
#  'dogs',
#  'beneath',
#  'owner',
#  'legs',
#  'feet',
#  'smiles',
#  'scissors',
#  'shirtless',
#  'pink',
#  'drinking',
#  'wrap',
#  'showing',
#  'bright',
#  'sweater',
#  'going',
#  'town',
#  'way',
#  'together',
#  'enjoying',
#  'company',
#  'video',
#  'watches',
#  'boys',
#  'play',
#  'singing',
#  'microphones',
#  'kids',
#  'crowd',
#  'prepare',
#  'ski',
#  'snow',
#  'slopes',
#  'skiiers',
#  'gathered',
#  'base',
#  'travel',
#  'climb',
#  'winter',
#  'ages',
#  'skiing',
#  'slope',
#  'gathering',
#  'neatly',
#  'stacked',
#  'shelf',
#  'stored',
#  'spa',
#  'jacuzzi',
#  'displayed',
#  'curtain',
#  'orange',
#  'gray',
#  'accents',
#  'bowl',
#  'pose',
#  'cake',
#  'older',
#  'blow',
#  'candle',
#  'birthday',
#  'besides',
#  'married',
#  'posing',
#  'smiling',
#  'celebrating',
#  'special',
#  'occasion',
#  'skate',
#  'seating',
#  'skateboard',
#  'doing',
#  'shirt',
#  'jeans',
#  'skateboarder',
#  'airborne',
#  'he',
#  'basket',
#  'against',
#  'stucco',
#  'keyboard',
#  'panel',
#  'pad',
#  'wireless',
#  'games',
#  'keys',
#  'lettering',
#  'sized',
#  'striped',
#  'surfers',
#  'ride',
#  'wade',
#  'sea',
#  'reflective',
#  'marble',
#  'tissue',
#  'dispenser',
#  'pantry',
#  'occupied',
#  'leading',
#  'visible',
#  'opening',
#  'shades',
#  'matching',
#  'shopping',
#  'center',
#  'plaza',
#  'stores',
#  'cloudy',
#  'mall',
#  'close',
#  'spiral',
#  'design',
#  'closed',
#  'falls',
#  'asleep',
#  'chihuahua',
#  'little',
#  'mans',
#  'nearly',
#  'hall',
#  'rooms',
#  'hallway',
#  'where',
#  'tires',
#  'teenage',
#  'wire',
#  'inspecting',
#  'project',
#  'checking',
#  'holds',
#  'leash',
#  'items',
#  'wires',
#  'poles',
#  'parade',
#  'soccer',
#  'fan',
#  'dressing',
#  'spacious',
#  'shiny',
#  'gold',
#  'were',
#  'captured',
#  'altered',
#  'resting',
#  'have',
#  'paws',
#  'groceries',
#  'downtown',
#  'crosswalk',
#  'bags',
#  'hands',
#  'intersection',
#  'busy',
#  'bikers',
#  'turn',
#  'competing',
#  'lots',
#  'space',
#  'unused',
#  'tropical',
#  'hold',
#  'attractive',
#  'herself',
#  'couch',
#  'spending',
#  'watching',
#  'lounge',
#  'staring',
#  'waking',
#  'passes',
#  'adults',
#  'asphalt',
#  'fridge',
#  'halfway',
#  'lower',
#  'oddly',
#  'shaped',
#  'pretty',
#  'porcelain',
#  'chair',
#  'court',
#  'park',
#  'skateboarding',
#  'spotless',
#  'storage',
#  'hits',
#  'big',
#  'catches',
#  'but',
#  'fall',
#  'flowering',
#  'nearby',
#  'quiet',
#  'highly',
#  'displaying',
#  'various',
#  'utensils',
#  'reflecting',
#  'opposite',
#  'toothbrushes',
#  'meal',
#  'natural',
#  'handicap',
#  'bar',
#  'rail',
#  'shining',
#  'drawers',
#  'makeup',
#  'cross',
#  'waits',
#  'bicyclist',
#  'wait',
#  'cooking',
#  'underneath',
#  'commercial',
#  'refrigerators',
#  'workstation',
#  'indicate',
#  'alone',
#  'paneled',
#  'made',
#  'planks',
#  'identical',
#  'bathing',
#  'fresh',
#  'assortment',
#  'lime',
#  'beautiful',
#  'blonde',
#  'glides',
#  'urban',
#  'following',
#  'cyclist',
#  'hat',
#  'pointed',
#  'head',
#  'traveling',
#  'stopped',
#  'approach',
#  'cone',
#  'barrier',
#  'suburban',
#  'blocked',
#  'tape',
#  'covering',
#  'plate',
#  'armor',
#  'helmet',
#  'knight',
#  'japanese',
#  'rust',
#  'filthy',
#  'alley',
#  'ledge',
#  'rusty',
#  'hard',
#  'beige',
#  'sheer',
#  'pictures',
#  'seen',
#  'heavily',
#  'cloths',
#  'coverings',
#  'tank',
#  'lid',
#  'ramp',
#  'reading',
#  'lap',
#  'baskets',
#  'goods',
#  'stack',
#  'beverages',
#  'drink',
#  'floors',
#  'standup',
#  'gentleman',
#  'alongside',
#  'male',
#  'dump',
#  'truck',
#  'banana',
#  'if',
#  'telephone',
#  'pretending',
#  'talk',
#  'though',
#  'ear',
#  'drying',
#  'cook',
#  'dinner',
#  'cluttered',
#  'dress',
#  'brushing',
#  'teeth',
#  'toothbrush',
#  'doll',
#  'cup',
#  'coffee',
#  'brushes',
#  'shines',
#  'fronted',
#  ...]

# %%
import keras
import pickle
from keras.preprocessing import image
oov_token = '<UNK>'
filters = '!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n' # to make sure all the last non digit non alphabet chars are removed
tokenizer = keras.preprocessing.text.Tokenizer(filters = filters, oov_token=oov_token)
tokenizer.fit_on_texts(vocab)
vocab_size = len(tokenizer.word_index) + 1
print('vocab_size :', vocab_size)
pickle.dump(tokenizer, open('process_data/word_tokenize.pkl', 'wb'))
# Out:
# vocab_size : 6306

# %%
# RUN THISSSSSS
with open('process_data/word_tokenize.pkl','rb') as f:
    tokenizer = pickle.load(f)  

vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 6306
